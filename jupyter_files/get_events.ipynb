# %% [markdown]
# Импорты и настройки

# %%
import requests
import pandas as pd
import numpy as np
import csv
import io
import ast

# %%
pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# Данные для для запроса

# %%
from_date = '2022-12-19'
to_date = '2022-12-25'


# ID Tez bol
# app_id = 'com.tezbol.android'  # Tez bol android
# token = 'Bearer eyJhbGciOiJBMjU2S1ciLCJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwidHlwIjoiSldUIiwiemlwIjoiREVGIn0.sEVLFBUJYOA0mqDnHXn26LmhHkk9brtcqEFUQ3ff28aHsMYW4IgcRQ.rHov5TPYLC05J7FU.kPdQbwAy_6DjqVQnHgOVPNh1hLwtSdKrSPIfwVBQx22brT5CfR0-QMnh_Gmz8zFvyKOYXY2JaIfKetASeZ2FM-6VxT8b7MmFESD-McDxnSa6x_HpAbAXT2D2oqK_x7uh7WWF4eVYQTgo6M5UL8qZyg_nBH1FC3BKUxo0NEnUWtdkxlk71GbcGtP7a0Ik1NNgh7f-uFfuDbh9Kx-RhV7m5Io14MuKoh9KW1SAo__N0g2yOk5_1KDgVhGSTPtyiI34FA1O-GB569ufliR4Yo2-i9mLoCWaiJHLltxE55rp39rqLgGQiSxBpAiG-c3gHB5n8cU9pqN4cvRpMMjOTxaAE6FZYM7WlTAx80Pmqy6yVXe3dBBH9UZjpFhc5aR84y-BYU0UnrODff2KT-EjTXap2nWI0ALZCC0LvX57FZk8ZQrlV1UG6tmx2_mXgQNkAuCYNzsgRajRUf3TjLNMEwVTpn-yCYbVo9YtKumwXu9bI-iHIKqPmvr8y466bA5_zYP7MQLG75jnKWbSr3VAf87VNA.VaZ4bKqcqdREmfgWC7bBDg'   


# #ID Kreditomat.KZ
# # app_id = 'id1392973739'   # kreditomat ios
app_id = 'com.payday.dozp.ref'   # kreditomat android
token = 'Bearer eyJhbGciOiJBMjU2S1ciLCJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwidHlwIjoiSldUIiwiemlwIjoiREVGIn0.sEVLFBUJYOA0mqDnHXn26LmhHkk9brtcqEFUQ3ff28aHsMYW4IgcRQ.rHov5TPYLC05J7FU.kPdQbwAy_6DjqVQnHgOVPNh1hLwtSdKrSPIfwVBQx22brT5CfR0-QMnh_Gmz8zFvyKOYXY2JaIfKetASeZ2FM-6VxT8b7MmFESD-McDxnSa6x_HpAbAXT2D2oqK_x7uh7WWF4eVYQTgo6M5UL8qZyg_nBH1FC3BKUxo0NEnUWtdkxlk71GbcGtP7a0Ik1NNgh7f-uFfuDbh9Kx-RhV7m5Io14MuKoh9KW1SAo__N0g2yOk5_1KDgVhGSTPtyiI34FA1O-GB569ufliR4Yo2-i9mLoCWaiJHLltxE55rp39rqLgGQiSxBpAiG-c3gHB5n8cU9pqN4cvRpMMjOTxaAE6FZYM7WlTAx80Pmqy6yVXe3dBBH9UZjpFhc5aR84y-BYU0UnrODff2KT-EjTXap2nWI0ALZCC0LvX57FZk8ZQrlV1UG6tmx2_mXgQNkAuCYNzsgRajRUf3TjLNMEwVTpn-yCYbVo9YtKumwXu9bI-iHIKqPmvr8y466bA5_zYP7MQLG75jnKWbSr3VAf87VNA.VaZ4bKqcqdREmfgWC7bBDg'   


# # #ID Creditomat.MD
# app_id = 'com.kreditomatmd.dozp.ref'   # MD kreditomat android
# token = 'Bearer eyJhbGciOiJBMjU2S1ciLCJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwidHlwIjoiSldUIiwiemlwIjoiREVGIn0.Hioi6Lb0C7wwtN6_9zoigB37ukPBlJdyF5R7G3DIncShFJtPNs9h9g.eqnAjdwd28XULE_-.IZsJsJuR5e-yVrcmWoDVe-DVURRjFEsQShgWwJ9unBkxAjz72n2IBrWecP7_pA9k6mV7br73JxgvWmPB6RNwTPcPOz0FbBQQIwX-xu2iD3udokHVk3XT5aP_aMHSWkADoeyJZyImnPf10-wCi8-nJ3vivzebPl6VCi5QQ-HorU5O8PLUq9LddE-0L7gfT6S0diMY7yW1HpAGHKethpI7abCwV9_yX88tptFHlaWV8zqsHysoqZmA-6tiyloCIoGOibFgk6Ix5tJYQaZkUFbvQf5IVdwoJVe-VeGEESnBedQA3UBbpAhHB1Hp1OZeZOBUpAOQHQRZkqNvy8y9QMMkr-5-_CS567ZAtUfh3ZbMcHau63e6fsQbbWQhDWeBZ6GDm5OuAIgyyJipAyEf7_6ozL0DS00wUYrhKH1vCF4kMid7VljHcVk2s_-2u79I2ttDsQtK3DGnbSYgsGkktkQDSKGCOlRLNNkpCnHp5bnhmLEbs-BpxwIlHW7PoNi3YQriaBLJrWt1Sn-T3j8N6lIwgFDG0A.sma12W1tpVnUAojhCVLMUA'

# %% [markdown]
# Запрос в Appsflyer

# %%
url = f"https://hq1.appsflyer.com/api/raw-data/export/app/{app_id}/in_app_events_report/v5?from={from_date}&to={to_date}&event_name=&reattr=false&additional_fields=blocked_reason_rule,store_reinstall,impressions,conversion_type,gp_click_time,match_type,mediation_network,oaid,deeplink_url,gp_install_begin,campaign_type,custom_data,device_download_time,device_model,monetization_network,segment,store_product_page,device_category"

headers = {
    "accept": "text/csv",
    "authorization": token}

urlData = requests.get(url, headers=headers).content
df = pd.read_csv(io.StringIO(urlData.decode('utf-8')), low_memory=False)

'''получаем ресурсы и меняем restricted на Facebook_Ad'''
sources = list(df['Media Source'].unique())
if 'restricted' in sources:
    ind = sources.index('restricted')
    sources[ind] = 'Facebook_Ads'
else:
    pass





sources
# Out:
# ['googleadwords_int',
#  'land_calcul',
#  'app_land',
#  'from_TezBol',
#  'Facebook_Ads',
#  'vk_int',
#  'app_land_Twogis',
#  'calcul_store',
#  'app_kms',
#  'FixedB',
#  'Facebook Ads',
#  'social-insta',
#  'app_land_poiskg',
#  'app_search',
#  'byyd_ads_int',
#  'None',
#  'qrcodland',
#  'poiskG',
#  'app_land_google-pr',
#  'google_search']

# %% [markdown]
# Выбор канала

# %%
'''меняем название restricted на Facebook_Ads в dataframe'''
r = list(df['Media Source'])
for i in range(len(r)):
    if r[i] == 'restricted':
        r[i] = 'Facebook_Ads'
    elif r[i] == 'Facebook Ads':
        r[i] = 'Facebook_Ads'
    else:
        r[i] = r[i]
df['Media Source'] = r
df.head(5)
# Out:
#   Attributed Touch Type Attributed Touch Time         Install Time  \
# 0                 click   2022-12-25 23:58:24  2022-12-25 23:59:03
# 1                 click   2022-12-25 23:58:24  2022-12-25 23:59:03
# 2                 click   2022-12-25 23:56:18  2022-12-25 23:58:57
# 3                 click   2022-12-24 14:48:56  2022-12-24 14:51:06
# 4                 click   2022-12-24 14:48:56  2022-12-24 14:51:06
#
#             Event Time          Event Name            Event Value  \
# 0  2022-12-25 23:59:31            af_login  {"ClientState":"New"}
# 1  2022-12-25 23:59:06  install_kreditomat  {"ClientState":"New"}
# 2  2022-12-25 23:59:00  install_kreditomat  {"ClientState":"New"}
# 3  2022-12-25 23:52:02            af_login  {"ClientState":"New"}
# 4  2022-12-25 23:51:29  install_kreditomat  {"ClientState":"New"}
#
#    Event Revenue Event Revenue Currency  Event Revenue USD Event Source  \
# 0            NaN                    USD                NaN          SDK
# 1            NaN                    USD                NaN          SDK
# 2            NaN                    USD                NaN          SDK
# 3            NaN                    USD                NaN          SDK
# 4            NaN                    USD                NaN          SDK
#
#    Is Receipt Validated  Partner       Media Source      Channel  Keywords  \
# 0                   NaN      NaN  googleadwords_int   ACI_Search       NaN
# 1                   NaN      NaN  googleadwords_int   ACI_Search       NaN
# 2                   NaN      NaN  googleadwords_int   ACI_Search       NaN
# 3                   NaN      NaN  googleadwords_int  ACI_Display       NaN
# 4                   NaN      NaN  googleadwords_int  ACI_Display       NaN
#
#               Campaign   Campaign ID                    Adset      Adset ID  \
# 0  Instal G first open  1.833112e+10            Ремонт машины  1.431682e+11
# 1  Instal G first open  1.833112e+10            Ремонт машины  1.431682e+11
# 2  Instal G first open  1.833112e+10            Ремонт машины  1.431682e+11
# 3  Instal G first open  1.832725e+10  Вам одобрен микрокредит  1.402261e+11
# 4  Instal G first open  1.832725e+10  Вам одобрен микрокредит  1.402261e+11
#
#    Ad Ad ID          Ad Type       Site ID  Sub Site ID  Sub Param 1  \
# 0 NaN   NaN  ClickToDownload  GoogleSearch          NaN          NaN
# 1 NaN   NaN  ClickToDownload  GoogleSearch          NaN          NaN
# 2 NaN   NaN  ClickToDownload  GoogleSearch          NaN          NaN
# 3 NaN   NaN  ClickToDownload           NaN          NaN          NaN
# 4 NaN   NaN  ClickToDownload           NaN          NaN          NaN
#
#    Sub Param 2  Sub Param 3  Sub Param 4 Sub Param 5  Cost Model  Cost Value  \
# 0          NaN          NaN          NaN         NaN         NaN         NaN
# 1          NaN          NaN          NaN         NaN         NaN         NaN
# 2          NaN          NaN          NaN         NaN         NaN         NaN
# 3          NaN          NaN          NaN         NaN         NaN         NaN
# 4          NaN          NaN          NaN         NaN         NaN         NaN
#
#    Cost Currency  Contributor 1 Partner  Contributor 1 Media Source  \
# 0            NaN                    NaN                         NaN
# 1            NaN                    NaN                         NaN
# 2            NaN                    NaN                         NaN
# 3            NaN                    NaN                         NaN
# 4            NaN                    NaN                         NaN
#
#    Contributor 1 Campaign  Contributor 1 Touch Type  Contributor 1 Touch Time  \
# 0                     NaN                       NaN                       NaN
# 1                     NaN                       NaN                       NaN
# 2                     NaN                       NaN                       NaN
# 3                     NaN                       NaN                       NaN
# 4                     NaN                       NaN                       NaN
#
#    Contributor 2 Partner  Contributor 2 Media Source  Contributor 2 Campaign  \
# 0                    NaN                         NaN                     NaN
# 1                    NaN                         NaN                     NaN
# 2                    NaN                         NaN                     NaN
# 3                    NaN                         NaN                     NaN
# 4                    NaN                         NaN                     NaN
#
#    Contributor 2 Touch Type  Contributor 2 Touch Time  Contributor 3 Partner  \
# 0                       NaN                       NaN                    NaN
# 1                       NaN                       NaN                    NaN
# 2                       NaN                       NaN                    NaN
# 3                       NaN                       NaN                    NaN
# 4                       NaN                       NaN                    NaN
#
#    Contributor 3 Media Source  Contributor 3 Campaign  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
#
#    Contributor 3 Touch Type  Contributor 3 Touch Time Region Country Code  \
# 0                       NaN                       NaN     AS           KZ
# 1                       NaN                       NaN     AS           KZ
# 2                       NaN                       NaN     AS           KZ
# 3                       NaN                       NaN     AS           KZ
# 4                       NaN                       NaN     AS           KZ
#
#   State       City Postal Code   DMA              IP  WIFI    Operator  \
# 0   ALM   Boraldai      040708  None   95.82.127.210  True  Beeline KZ
# 1   ALM   Boraldai      040708  None   95.82.127.210  True  Beeline KZ
# 2   MAN  Zhanaozen      130202  None  194.39.108.132  True       Tele2
# 3   YUZ    Tasaryk      161113  None    95.82.92.122  True  Beeline KZ
# 4   YUZ    Tasaryk      161113  None    95.82.92.122  True  Beeline KZ
#
#       Carrier Language                       AppsFlyer ID  \
# 0  Beeline KZ  русский  1672012738372-1934286870111148416
# 1  Beeline KZ  русский  1672012738372-1934286870111148416
# 2       Tele2  русский  1672012735462-2269115973090293949
# 3   BeelineKZ  русский  1671893461877-1527471239897430085
# 4   BeelineKZ  русский  1671893461877-1527471239897430085
#
#                          Advertising ID  IDFA Android ID  Customer User ID  \
# 0  b02e2dc3-d600-4c5b-bd34-fc7b12173844   NaN        NaN               NaN
# 1  b02e2dc3-d600-4c5b-bd34-fc7b12173844   NaN        NaN               NaN
# 2  2ea82004-4ced-4cb8-948c-b9c2ad65abd3   NaN        NaN               NaN
# 3  a9d71650-41ad-4e12-8115-dac32bb64d6b   NaN        NaN               NaN
# 4  a9d71650-41ad-4e12-8115-dac32bb64d6b   NaN        NaN               NaN
#
#    IMEI  IDFV Platform  Device Type OS Version App Version SDK Version  \
# 0   NaN   NaN  android          NaN         11     2.0.2.1      v6.2.0
# 1   NaN   NaN  android          NaN         11     2.0.2.1      v6.2.0
# 2   NaN   NaN  android          NaN         11     2.0.2.1      v6.2.0
# 3   NaN   NaN  android          NaN         12     2.0.2.1      v6.2.0
# 4   NaN   NaN  android          NaN         12     2.0.2.1      v6.2.0
#
#                 App ID                                           App Name  \
# 0  com.payday.dozp.ref  Kreditomat.kz - кредит онлайн на карту и налич...
# 1  com.payday.dozp.ref  Kreditomat.kz - кредит онлайн на карту и налич...
# 2  com.payday.dozp.ref  Kreditomat.kz - кредит онлайн на карту и налич...
# 3  com.payday.dozp.ref  Kreditomat.kz - кредит онлайн на карту и налич...
# 4  com.payday.dozp.ref  Kreditomat.kz - кредит онлайн на карту и налич...
#
#              Bundle ID  Is Retargeting  Retargeting Conversion Type  \
# 0  com.payday.dozp.ref           False                          NaN
# 1  com.payday.dozp.ref           False                          NaN
# 2  com.payday.dozp.ref           False                          NaN
# 3  com.payday.dozp.ref           False                          NaN
# 4  com.payday.dozp.ref           False                          NaN
#
#   Attribution Lookback  Reengagement Window  Is Primary Attribution  \
# 0                  30d                  NaN                    True
# 1                  30d                  NaN                    True
# 2                  30d                  NaN                    True
# 3                  30d                  NaN                    True
# 4                  30d                  NaN                    True
#
#                                           User Agent HTTP Referrer  \
# 0  Dalvik/2.1.0 (Linux; U; Android 11; 21121119SG...           NaN
# 1  Dalvik/2.1.0 (Linux; U; Android 11; 21121119SG...           NaN
# 2  Dalvik/2.1.0 (Linux; U; Android 11; SM-A405FN ...           NaN
# 3  Dalvik/2.1.0 (Linux; U; Android 12; SM-A325F B...           NaN
# 4  Dalvik/2.1.0 (Linux; U; Android 12; SM-A325F B...           NaN
#
#   Original URL  Blocked Reason Rule  Store Reinstall  Impressions  \
# 0          NaN                  NaN              NaN          NaN
# 1          NaN                  NaN              NaN          NaN
# 2          NaN                  NaN              NaN          NaN
# 3          NaN                  NaN              NaN          NaN
# 4          NaN                  NaN              NaN          NaN
#
#   Conversion Type  Google Play Click Time Match Type  Mediation Network  OAID  \
# 0         install                     NaN        srn                NaN   NaN
# 1         install                     NaN        srn                NaN   NaN
# 2         install                     NaN        srn                NaN   NaN
# 3         install                     NaN        srn                NaN   NaN
# 4         install                     NaN        srn                NaN   NaN
#
#    Deeplink URL  Google Play Install Begin Time Campaign Type  Custom Data  \
# 0           NaN                             NaN            ua          NaN
# 1           NaN                             NaN            ua          NaN
# 2           NaN                             NaN            ua          NaN
# 3           NaN                             NaN            ua          NaN
# 4           NaN                             NaN            ua          NaN
#
#       Device Download Time        Device Model  Monetization Network  Segment  \
# 0  2022-12-25 23:58:45.000   Redmi::21121119SG                   NaN      NaN
# 1  2022-12-25 23:58:45.000   Redmi::21121119SG                   NaN      NaN
# 2  2022-12-25 23:57:00.000  samsung::SM-A405FN                   NaN      NaN
# 3  2022-12-24 14:50:55.000   samsung::SM-A325F                   NaN      NaN
# 4  2022-12-24 14:50:55.000   samsung::SM-A325F                   NaN      NaN
#
#    Store Product Page Device Category
# 0                 NaN           phone
# 1                 NaN           phone
# 2                 NaN           phone
# 3                 NaN           phone
# 4                 NaN           phone

# %%
df_filter = df.loc[df['Media Source'] == 'Facebook_Ads']

df_filter.head(5)
df_filter
# Out:
#       Attributed Touch Type Attributed Touch Time         Install Time  \
# 99                      NaN                   NaN  2022-12-25 21:42:12
# 100                     NaN                   NaN  2022-12-25 21:42:12
# 101                     NaN                   NaN  2022-12-25 21:33:16
# 102                     NaN                   NaN  2022-12-25 21:33:16
# 220                     NaN                   NaN  2022-12-25 20:02:03
# ...                     ...                   ...                  ...
# 26529                   NaN                   NaN  2022-09-29 07:48:33
# 26530                   NaN                   NaN  2022-09-29 07:48:33
# 26535                   NaN                   NaN  2022-09-29 07:48:33
# 26538                   NaN                   NaN  2022-09-29 07:48:33
# 26540                   NaN                   NaN  2022-09-29 07:48:33
#
#                 Event Time               Event Name  \
# 99     2022-12-25 21:42:36                 af_login
# 100    2022-12-25 21:42:18       install_kreditomat
# 101    2022-12-25 21:33:46                 af_login
# 102    2022-12-25 21:33:21       install_kreditomat
# 220    2022-12-25 20:12:16                 af_login
# ...                    ...                      ...
# 26529  2022-12-19 03:20:15            loan_accepted
# 26530  2022-12-19 03:20:12        payment_completed
# 26535  2022-12-19 03:18:51  submit_loan_application
# 26538  2022-12-19 03:17:02                 af_login
# 26540  2022-12-19 03:14:06                 af_login
#
#                                              Event Value  Event Revenue  \
# 99                                 {"ClientState":"New"}            NaN
# 100                                {"ClientState":"New"}            NaN
# 101                                {"ClientState":"New"}            NaN
# 102                                {"ClientState":"New"}            NaN
# 220                                {"ClientState":"Old"}            NaN
# ...                                                  ...            ...
# 26529  {"loan_client_id":"1583630","loam_amount":"480...            NaN
# 26530  {"loan_client_id":"1583630","loam_amount":"480...            NaN
# 26535  {"loan_client_id":"1583630","loam_amount":4800...            NaN
# 26538                              {"ClientState":"Old"}            NaN
# 26540                              {"ClientState":"Old"}            NaN
#
#       Event Revenue Currency  Event Revenue USD Event Source  \
# 99                       USD                NaN          SDK
# 100                      USD                NaN          SDK
# 101                      USD                NaN          SDK
# 102                      USD                NaN          SDK
# 220                      USD                NaN          SDK
# ...                      ...                ...          ...
# 26529                    USD                NaN          SDK
# 26530                    USD                NaN          SDK
# 26535                    USD                NaN          SDK
# 26538                    USD                NaN          SDK
# 26540                    USD                NaN          SDK
#
#        Is Receipt Validated  Partner  Media Source Channel  Keywords Campaign  \
# 99                      NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# 100                     NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# 101                     NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# 102                     NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# 220                     NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# ...                     ...      ...           ...     ...       ...      ...
# 26529                   NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# 26530                   NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# 26535                   NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# 26538                   NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# 26540                   NaN      NaN  Facebook_Ads     NaN       NaN      NaN
#
#        Campaign ID Adset  Adset ID  Ad Ad ID Ad Type Site ID  Sub Site ID  \
# 99             NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# 100            NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# 101            NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# 102            NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# 220            NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# ...            ...   ...       ...  ..   ...     ...     ...          ...
# 26529          NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# 26530          NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# 26535          NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# 26538          NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# 26540          NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
#
#        Sub Param 1  Sub Param 2  Sub Param 3  Sub Param 4 Sub Param 5  \
# 99             NaN          NaN          NaN          NaN         NaN
# 100            NaN          NaN          NaN          NaN         NaN
# 101            NaN          NaN          NaN          NaN         NaN
# 102            NaN          NaN          NaN          NaN         NaN
# 220            NaN          NaN          NaN          NaN         NaN
# ...            ...          ...          ...          ...         ...
# 26529          NaN          NaN          NaN          NaN         NaN
# 26530          NaN          NaN          NaN          NaN         NaN
# 26535          NaN          NaN          NaN          NaN         NaN
# 26538          NaN          NaN          NaN          NaN         NaN
# 26540          NaN          NaN          NaN          NaN         NaN
#
#        Cost Model  Cost Value  Cost Currency  Contributor 1 Partner  \
# 99            NaN         NaN            NaN                    NaN
# 100           NaN         NaN            NaN                    NaN
# 101           NaN         NaN            NaN                    NaN
# 102           NaN         NaN            NaN                    NaN
# 220           NaN         NaN            NaN                    NaN
# ...           ...         ...            ...                    ...
# 26529         NaN         NaN            NaN                    NaN
# 26530         NaN         NaN            NaN                    NaN
# 26535         NaN         NaN            NaN                    NaN
# 26538         NaN         NaN            NaN                    NaN
# 26540         NaN         NaN            NaN                    NaN
#
#        Contributor 1 Media Source  Contributor 1 Campaign  \
# 99                            NaN                     NaN
# 100                           NaN                     NaN
# 101                           NaN                     NaN
# 102                           NaN                     NaN
# 220                           NaN                     NaN
# ...                           ...                     ...
# 26529                         NaN                     NaN
# 26530                         NaN                     NaN
# 26535                         NaN                     NaN
# 26538                         NaN                     NaN
# 26540                         NaN                     NaN
#
#        Contributor 1 Touch Type  Contributor 1 Touch Time  \
# 99                          NaN                       NaN
# 100                         NaN                       NaN
# 101                         NaN                       NaN
# 102                         NaN                       NaN
# 220                         NaN                       NaN
# ...                         ...                       ...
# 26529                       NaN                       NaN
# 26530                       NaN                       NaN
# 26535                       NaN                       NaN
# 26538                       NaN                       NaN
# 26540                       NaN                       NaN
#
#        Contributor 2 Partner  Contributor 2 Media Source  \
# 99                       NaN                         NaN
# 100                      NaN                         NaN
# 101                      NaN                         NaN
# 102                      NaN                         NaN
# 220                      NaN                         NaN
# ...                      ...                         ...
# 26529                    NaN                         NaN
# 26530                    NaN                         NaN
# 26535                    NaN                         NaN
# 26538                    NaN                         NaN
# 26540                    NaN                         NaN
#
#        Contributor 2 Campaign  Contributor 2 Touch Type  \
# 99                        NaN                       NaN
# 100                       NaN                       NaN
# 101                       NaN                       NaN
# 102                       NaN                       NaN
# 220                       NaN                       NaN
# ...                       ...                       ...
# 26529                     NaN                       NaN
# 26530                     NaN                       NaN
# 26535                     NaN                       NaN
# 26538                     NaN                       NaN
# 26540                     NaN                       NaN
#
#        Contributor 2 Touch Time  Contributor 3 Partner  \
# 99                          NaN                    NaN
# 100                         NaN                    NaN
# 101                         NaN                    NaN
# 102                         NaN                    NaN
# 220                         NaN                    NaN
# ...                         ...                    ...
# 26529                       NaN                    NaN
# 26530                       NaN                    NaN
# 26535                       NaN                    NaN
# 26538                       NaN                    NaN
# 26540                       NaN                    NaN
#
#        Contributor 3 Media Source  Contributor 3 Campaign  \
# 99                            NaN                     NaN
# 100                           NaN                     NaN
# 101                           NaN                     NaN
# 102                           NaN                     NaN
# 220                           NaN                     NaN
# ...                           ...                     ...
# 26529                         NaN                     NaN
# 26530                         NaN                     NaN
# 26535                         NaN                     NaN
# 26538                         NaN                     NaN
# 26540                         NaN                     NaN
#
#        Contributor 3 Touch Type  Contributor 3 Touch Time Region Country Code  \
# 99                          NaN                       NaN     AS           KZ
# 100                         NaN                       NaN     AS           KZ
# 101                         NaN                       NaN     AS           KZ
# 102                         NaN                       NaN     AS           KZ
# 220                         NaN                       NaN     AS           KZ
# ...                         ...                       ...    ...          ...
# 26529                       NaN                       NaN     AS           KZ
# 26530                       NaN                       NaN     AS           KZ
# 26535                       NaN                       NaN     AS           KZ
# 26538                       NaN                       NaN     AS           KZ
# 26540                       NaN                       NaN     AS           KZ
#
#       State        City Postal Code   DMA             IP   WIFI    Operator  \
# 99      ATY      Atyrau      060000  None   5.251.37.189   True       activ
# 100     ATY      Atyrau      060000  None   5.251.37.189   True       activ
# 101     VOS  Belousovka      070503  None   89.42.61.106  False  Beeline KZ
# 102     VOS  Belousovka      070503  None   89.42.61.106  False  Beeline KZ
# 220     SHY    Shymkent      160000  None   95.82.88.209   True       Tele2
# ...     ...         ...         ...   ...            ...    ...         ...
# 26529   KAR   Samarkand      100434  None  89.42.205.215  False       Tele2
# 26530   KAR   Samarkand      100434  None  89.42.205.215  False       Tele2
# 26535   KAR   Samarkand      100434  None  89.42.205.215  False       Tele2
# 26538   KAR   Samarkand      100434  None  89.42.205.215  False       Tele2
# 26540   KAR   Samarkand      100434  None  89.42.205.215  False       Tele2
#
#           Carrier Language                       AppsFlyer ID  \
# 99          KCELL  русский  1672004529492-6465594982591427015
# 100         KCELL  русский  1672004529492-6465594982591427015
# 101    Beeline KZ  русский  1672003994208-1367048169775550711
# 102    Beeline KZ  русский  1672003994208-1367048169775550711
# 220         Tele2  русский  1671998521400-7870800315447302341
# ...           ...      ...                                ...
# 26529       Tele2  русский  1664437710369-2480551812467612594
# 26530       Tele2  русский  1664437710369-2480551812467612594
# 26535       Tele2  русский  1664437710369-2480551812467612594
# 26538       Tele2  русский  1664437710369-2480551812467612594
# 26540       Tele2       kz  1664437710369-2480551812467612594
#
#                              Advertising ID  IDFA Android ID  \
# 99     437c230d-9cf2-4c5c-9124-a858ecf1e47c   NaN        NaN
# 100    437c230d-9cf2-4c5c-9124-a858ecf1e47c   NaN        NaN
# 101    294b8859-29af-44fe-8eac-49a108327d15   NaN        NaN
# 102    294b8859-29af-44fe-8eac-49a108327d15   NaN        NaN
# 220    63a1d25d-9a0c-41c9-a367-cd192b18d7c6   NaN        NaN
# ...                                     ...   ...        ...
# 26529  d5a1b9f1-af0e-41b0-88e8-e42f614423f1   NaN        NaN
# 26530  d5a1b9f1-af0e-41b0-88e8-e42f614423f1   NaN        NaN
# 26535  d5a1b9f1-af0e-41b0-88e8-e42f614423f1   NaN        NaN
# 26538  d5a1b9f1-af0e-41b0-88e8-e42f614423f1   NaN        NaN
# 26540  d5a1b9f1-af0e-41b0-88e8-e42f614423f1   NaN        NaN
#
#        Customer User ID  IMEI  IDFV Platform  Device Type OS Version  \
# 99                  NaN   NaN   NaN  android          NaN         11
# 100                 NaN   NaN   NaN  android          NaN         11
# 101                 NaN   NaN   NaN  android          NaN         11
# 102                 NaN   NaN   NaN  android          NaN         11
# 220           1153686.0   NaN   NaN  android          NaN         12
# ...                 ...   ...   ...      ...          ...        ...
# 26529         1583630.0   NaN   NaN  android          NaN         10
# 26530         1583630.0   NaN   NaN  android          NaN         10
# 26535         1583630.0   NaN   NaN  android          NaN         10
# 26538         1583630.0   NaN   NaN  android          NaN         10
# 26540         1583630.0   NaN   NaN  android          NaN         10
#
#       App Version SDK Version               App ID  \
# 99        2.0.2.1      v6.2.0  com.payday.dozp.ref
# 100       2.0.2.1      v6.2.0  com.payday.dozp.ref
# 101       2.0.2.1      v6.2.0  com.payday.dozp.ref
# 102       2.0.2.1      v6.2.0  com.payday.dozp.ref
# 220       2.0.2.3      v6.2.0  com.payday.dozp.ref
# ...           ...         ...                  ...
# 26529     2.0.1.4      v6.2.0  com.payday.dozp.ref
# 26530     2.0.1.4      v6.2.0  com.payday.dozp.ref
# 26535     2.0.1.4      v6.2.0  com.payday.dozp.ref
# 26538     2.0.1.4      v6.2.0  com.payday.dozp.ref
# 26540     2.0.1.4      v6.2.0  com.payday.dozp.ref
#
#                                                 App Name            Bundle ID  \
# 99     Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# 100    Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# 101    Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# 102    Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# 220    Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# ...                                                  ...                  ...
# 26529  Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# 26530  Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# 26535  Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# 26538  Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# 26540  Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
#
#        Is Retargeting  Retargeting Conversion Type Attribution Lookback  \
# 99              False                          NaN                  NaN
# 100             False                          NaN                  NaN
# 101             False                          NaN                  NaN
# 102             False                          NaN                  NaN
# 220             False                          NaN                  NaN
# ...               ...                          ...                  ...
# 26529           False                          NaN                  NaN
# 26530           False                          NaN                  NaN
# 26535           False                          NaN                  NaN
# 26538           False                          NaN                  NaN
# 26540           False                          NaN                  NaN
#
#        Reengagement Window  Is Primary Attribution  \
# 99                     NaN                    True
# 100                    NaN                    True
# 101                    NaN                    True
# 102                    NaN                    True
# 220                    NaN                    True
# ...                    ...                     ...
# 26529                  NaN                    True
# 26530                  NaN                    True
# 26535                  NaN                    True
# 26538                  NaN                    True
# 26540                  NaN                    True
#
#                                               User Agent HTTP Referrer  \
# 99     Dalvik/2.1.0 (Linux; U; Android 11; SM-A505FM ...           NaN
# 100    Dalvik/2.1.0 (Linux; U; Android 11; SM-A505FM ...           NaN
# 101    Dalvik/2.1.0 (Linux; U; Android 11; 21061119AG...           NaN
# 102    Dalvik/2.1.0 (Linux; U; Android 11; 21061119AG...           NaN
# 220    Dalvik/2.1.0 (Linux; U; Android 12; 2201117TG ...           NaN
# ...                                                  ...           ...
# 26529  Dalvik/2.1.0 (Linux; U; Android 10; M2006C3MG ...           NaN
# 26530  Dalvik/2.1.0 (Linux; U; Android 10; M2006C3MG ...           NaN
# 26535  Dalvik/2.1.0 (Linux; U; Android 10; M2006C3MG ...           NaN
# 26538  Dalvik/2.1.0 (Linux; U; Android 10; M2006C3MG ...           NaN
# 26540  Dalvik/2.1.0 (Linux; U; Android 10; M2006C3MG ...           NaN
#
#       Original URL  Blocked Reason Rule  Store Reinstall  Impressions  \
# 99             NaN                  NaN              NaN          NaN
# 100            NaN                  NaN              NaN          NaN
# 101            NaN                  NaN              NaN          NaN
# 102            NaN                  NaN              NaN          NaN
# 220            NaN                  NaN              NaN          NaN
# ...            ...                  ...              ...          ...
# 26529          NaN                  NaN              NaN          NaN
# 26530          NaN                  NaN              NaN          NaN
# 26535          NaN                  NaN              NaN          NaN
# 26538          NaN                  NaN              NaN          NaN
# 26540          NaN                  NaN              NaN          NaN
#
#       Conversion Type  Google Play Click Time Match Type  Mediation Network  \
# 99            install                     NaN        NaN                NaN
# 100           install                     NaN        NaN                NaN
# 101           install                     NaN        NaN                NaN
# 102           install                     NaN        NaN                NaN
# 220           install                     NaN        NaN                NaN
# ...               ...                     ...        ...                ...
# 26529         install                     NaN        NaN                NaN
# 26530         install                     NaN        NaN                NaN
# 26535         install                     NaN        NaN                NaN
# 26538         install                     NaN        NaN                NaN
# 26540         install                     NaN        NaN                NaN
#
#        OAID  Deeplink URL  Google Play Install Begin Time Campaign Type  \
# 99      NaN           NaN                             NaN            ua
# 100     NaN           NaN                             NaN            ua
# 101     NaN           NaN                             NaN            ua
# 102     NaN           NaN                             NaN            ua
# 220     NaN           NaN                             NaN            ua
# ...     ...           ...                             ...           ...
# 26529   NaN           NaN                             NaN            ua
# 26530   NaN           NaN                             NaN            ua
# 26535   NaN           NaN                             NaN            ua
# 26538   NaN           NaN                             NaN            ua
# 26540   NaN           NaN                             NaN            ua
#
#        Custom Data     Device Download Time        Device Model  \
# 99             NaN  2022-12-25 21:42:01.000  samsung::SM-A505FM
# 100            NaN  2022-12-25 21:42:01.000  samsung::SM-A505FM
# 101            NaN  2022-12-25 21:32:58.000   Redmi::21061119AG
# 102            NaN  2022-12-25 21:32:58.000   Redmi::21061119AG
# 220            NaN  2022-12-25 20:01:43.000    Redmi::2201117TG
# ...            ...                      ...                 ...
# 26529          NaN  2022-09-29 07:47:41.000    Redmi::M2006C3MG
# 26530          NaN  2022-09-29 07:47:41.000    Redmi::M2006C3MG
# 26535          NaN  2022-09-29 07:47:41.000    Redmi::M2006C3MG
# 26538          NaN  2022-09-29 07:47:41.000    Redmi::M2006C3MG
# 26540          NaN  2022-09-29 07:47:41.000    Redmi::M2006C3MG
#
#        Monetization Network  Segment  Store Product Page Device Category  \
# 99                      NaN      NaN                 NaN           phone
# 100                     NaN      NaN                 NaN           phone
# 101                     NaN      NaN                 NaN           phone
# 102                     NaN      NaN                 NaN           phone
# 220                     NaN      NaN                 NaN           phone
# ...                     ...      ...                 ...             ...
# 26529                   NaN      NaN                 NaN           phone
# 26530                   NaN      NaN                 NaN           phone
# 26535                   NaN      NaN                 NaN           phone
# 26538                   NaN      NaN                 NaN           phone
# 26540                   NaN      NaN                 NaN           phone
#
#       ClientState loam_amount  loan_period
# 99            New         NaN          NaN
# 100           New         NaN          NaN
# 101           New         NaN          NaN
# 102           New         NaN          NaN
# 220           Old         NaN          NaN
# ...           ...         ...          ...
# 26529         NaN       48000         21.0
# 26530         NaN       48000         21.0
# 26535         NaN       48000         21.0
# 26538         Old         NaN          NaN
# 26540         Old         NaN          NaN
#
# [1526 rows x 102 columns]

# %%
# import ast
# for i in df["Event Value"].to_list():
#     print(i)

# type(ast.literal_eval(df.iloc[1,5]))

# %%
# for i in range(len(df)):
#     # print(df.iloc[i,5])
#     if 'null' in df.iloc[i,5]:
#         df.iloc[i,5] = df.iloc[i,5].replace('null', 'None')
#     else:
#         pass
#     element = ast.literal_eval(str(df.iloc[i,5]))
#     print(element)

# %%
df_filter.tail(5)
# Out:
#       Attributed Touch Type Attributed Touch Time         Install Time  \
# 26529                   NaN                   NaN  2022-09-29 07:48:33
# 26530                   NaN                   NaN  2022-09-29 07:48:33
# 26535                   NaN                   NaN  2022-09-29 07:48:33
# 26538                   NaN                   NaN  2022-09-29 07:48:33
# 26540                   NaN                   NaN  2022-09-29 07:48:33
#
#                 Event Time               Event Name  \
# 26529  2022-12-19 03:20:15            loan_accepted
# 26530  2022-12-19 03:20:12        payment_completed
# 26535  2022-12-19 03:18:51  submit_loan_application
# 26538  2022-12-19 03:17:02                 af_login
# 26540  2022-12-19 03:14:06                 af_login
#
#                                              Event Value  Event Revenue  \
# 26529  {"loan_client_id":"1583630","loam_amount":"480...            NaN
# 26530  {"loan_client_id":"1583630","loam_amount":"480...            NaN
# 26535  {"loan_client_id":"1583630","loam_amount":4800...            NaN
# 26538                              {"ClientState":"Old"}            NaN
# 26540                              {"ClientState":"Old"}            NaN
#
#       Event Revenue Currency  Event Revenue USD Event Source  \
# 26529                    USD                NaN          SDK
# 26530                    USD                NaN          SDK
# 26535                    USD                NaN          SDK
# 26538                    USD                NaN          SDK
# 26540                    USD                NaN          SDK
#
#        Is Receipt Validated  Partner  Media Source Channel  Keywords Campaign  \
# 26529                   NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# 26530                   NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# 26535                   NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# 26538                   NaN      NaN  Facebook_Ads     NaN       NaN      NaN
# 26540                   NaN      NaN  Facebook_Ads     NaN       NaN      NaN
#
#        Campaign ID Adset  Adset ID  Ad Ad ID Ad Type Site ID  Sub Site ID  \
# 26529          NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# 26530          NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# 26535          NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# 26538          NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
# 26540          NaN   NaN       NaN NaN   NaN     NaN     NaN          NaN
#
#        Sub Param 1  Sub Param 2  Sub Param 3  Sub Param 4 Sub Param 5  \
# 26529          NaN          NaN          NaN          NaN         NaN
# 26530          NaN          NaN          NaN          NaN         NaN
# 26535          NaN          NaN          NaN          NaN         NaN
# 26538          NaN          NaN          NaN          NaN         NaN
# 26540          NaN          NaN          NaN          NaN         NaN
#
#        Cost Model  Cost Value  Cost Currency  Contributor 1 Partner  \
# 26529         NaN         NaN            NaN                    NaN
# 26530         NaN         NaN            NaN                    NaN
# 26535         NaN         NaN            NaN                    NaN
# 26538         NaN         NaN            NaN                    NaN
# 26540         NaN         NaN            NaN                    NaN
#
#        Contributor 1 Media Source  Contributor 1 Campaign  \
# 26529                         NaN                     NaN
# 26530                         NaN                     NaN
# 26535                         NaN                     NaN
# 26538                         NaN                     NaN
# 26540                         NaN                     NaN
#
#        Contributor 1 Touch Type  Contributor 1 Touch Time  \
# 26529                       NaN                       NaN
# 26530                       NaN                       NaN
# 26535                       NaN                       NaN
# 26538                       NaN                       NaN
# 26540                       NaN                       NaN
#
#        Contributor 2 Partner  Contributor 2 Media Source  \
# 26529                    NaN                         NaN
# 26530                    NaN                         NaN
# 26535                    NaN                         NaN
# 26538                    NaN                         NaN
# 26540                    NaN                         NaN
#
#        Contributor 2 Campaign  Contributor 2 Touch Type  \
# 26529                     NaN                       NaN
# 26530                     NaN                       NaN
# 26535                     NaN                       NaN
# 26538                     NaN                       NaN
# 26540                     NaN                       NaN
#
#        Contributor 2 Touch Time  Contributor 3 Partner  \
# 26529                       NaN                    NaN
# 26530                       NaN                    NaN
# 26535                       NaN                    NaN
# 26538                       NaN                    NaN
# 26540                       NaN                    NaN
#
#        Contributor 3 Media Source  Contributor 3 Campaign  \
# 26529                         NaN                     NaN
# 26530                         NaN                     NaN
# 26535                         NaN                     NaN
# 26538                         NaN                     NaN
# 26540                         NaN                     NaN
#
#        Contributor 3 Touch Type  Contributor 3 Touch Time Region Country Code  \
# 26529                       NaN                       NaN     AS           KZ
# 26530                       NaN                       NaN     AS           KZ
# 26535                       NaN                       NaN     AS           KZ
# 26538                       NaN                       NaN     AS           KZ
# 26540                       NaN                       NaN     AS           KZ
#
#       State       City Postal Code   DMA             IP   WIFI Operator  \
# 26529   KAR  Samarkand      100434  None  89.42.205.215  False    Tele2
# 26530   KAR  Samarkand      100434  None  89.42.205.215  False    Tele2
# 26535   KAR  Samarkand      100434  None  89.42.205.215  False    Tele2
# 26538   KAR  Samarkand      100434  None  89.42.205.215  False    Tele2
# 26540   KAR  Samarkand      100434  None  89.42.205.215  False    Tele2
#
#       Carrier Language                       AppsFlyer ID  \
# 26529   Tele2  русский  1664437710369-2480551812467612594
# 26530   Tele2  русский  1664437710369-2480551812467612594
# 26535   Tele2  русский  1664437710369-2480551812467612594
# 26538   Tele2  русский  1664437710369-2480551812467612594
# 26540   Tele2       kz  1664437710369-2480551812467612594
#
#                              Advertising ID  IDFA Android ID  \
# 26529  d5a1b9f1-af0e-41b0-88e8-e42f614423f1   NaN        NaN
# 26530  d5a1b9f1-af0e-41b0-88e8-e42f614423f1   NaN        NaN
# 26535  d5a1b9f1-af0e-41b0-88e8-e42f614423f1   NaN        NaN
# 26538  d5a1b9f1-af0e-41b0-88e8-e42f614423f1   NaN        NaN
# 26540  d5a1b9f1-af0e-41b0-88e8-e42f614423f1   NaN        NaN
#
#        Customer User ID  IMEI  IDFV Platform  Device Type OS Version  \
# 26529         1583630.0   NaN   NaN  android          NaN         10
# 26530         1583630.0   NaN   NaN  android          NaN         10
# 26535         1583630.0   NaN   NaN  android          NaN         10
# 26538         1583630.0   NaN   NaN  android          NaN         10
# 26540         1583630.0   NaN   NaN  android          NaN         10
#
#       App Version SDK Version               App ID  \
# 26529     2.0.1.4      v6.2.0  com.payday.dozp.ref
# 26530     2.0.1.4      v6.2.0  com.payday.dozp.ref
# 26535     2.0.1.4      v6.2.0  com.payday.dozp.ref
# 26538     2.0.1.4      v6.2.0  com.payday.dozp.ref
# 26540     2.0.1.4      v6.2.0  com.payday.dozp.ref
#
#                                                 App Name            Bundle ID  \
# 26529  Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# 26530  Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# 26535  Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# 26538  Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
# 26540  Kreditomat.kz - кредит онлайн на карту и налич...  com.payday.dozp.ref
#
#        Is Retargeting  Retargeting Conversion Type Attribution Lookback  \
# 26529           False                          NaN                  NaN
# 26530           False                          NaN                  NaN
# 26535           False                          NaN                  NaN
# 26538           False                          NaN                  NaN
# 26540           False                          NaN                  NaN
#
#        Reengagement Window  Is Primary Attribution  \
# 26529                  NaN                    True
# 26530                  NaN                    True
# 26535                  NaN                    True
# 26538                  NaN                    True
# 26540                  NaN                    True
#
#                                               User Agent HTTP Referrer  \
# 26529  Dalvik/2.1.0 (Linux; U; Android 10; M2006C3MG ...           NaN
# 26530  Dalvik/2.1.0 (Linux; U; Android 10; M2006C3MG ...           NaN
# 26535  Dalvik/2.1.0 (Linux; U; Android 10; M2006C3MG ...           NaN
# 26538  Dalvik/2.1.0 (Linux; U; Android 10; M2006C3MG ...           NaN
# 26540  Dalvik/2.1.0 (Linux; U; Android 10; M2006C3MG ...           NaN
#
#       Original URL  Blocked Reason Rule  Store Reinstall  Impressions  \
# 26529          NaN                  NaN              NaN          NaN
# 26530          NaN                  NaN              NaN          NaN
# 26535          NaN                  NaN              NaN          NaN
# 26538          NaN                  NaN              NaN          NaN
# 26540          NaN                  NaN              NaN          NaN
#
#       Conversion Type  Google Play Click Time Match Type  Mediation Network  \
# 26529         install                     NaN        NaN                NaN
# 26530         install                     NaN        NaN                NaN
# 26535         install                     NaN        NaN                NaN
# 26538         install                     NaN        NaN                NaN
# 26540         install                     NaN        NaN                NaN
#
#        OAID  Deeplink URL  Google Play Install Begin Time Campaign Type  \
# 26529   NaN           NaN                             NaN            ua
# 26530   NaN           NaN                             NaN            ua
# 26535   NaN           NaN                             NaN            ua
# 26538   NaN           NaN                             NaN            ua
# 26540   NaN           NaN                             NaN            ua
#
#        Custom Data     Device Download Time      Device Model  \
# 26529          NaN  2022-09-29 07:47:41.000  Redmi::M2006C3MG
# 26530          NaN  2022-09-29 07:47:41.000  Redmi::M2006C3MG
# 26535          NaN  2022-09-29 07:47:41.000  Redmi::M2006C3MG
# 26538          NaN  2022-09-29 07:47:41.000  Redmi::M2006C3MG
# 26540          NaN  2022-09-29 07:47:41.000  Redmi::M2006C3MG
#
#        Monetization Network  Segment  Store Product Page Device Category  \
# 26529                   NaN      NaN                 NaN           phone
# 26530                   NaN      NaN                 NaN           phone
# 26535                   NaN      NaN                 NaN           phone
# 26538                   NaN      NaN                 NaN           phone
# 26540                   NaN      NaN                 NaN           phone
#
#       ClientState loam_amount  loan_period
# 26529         NaN       48000         21.0
# 26530         NaN       48000         21.0
# 26535         NaN       48000         21.0
# 26538         Old         NaN          NaN
# 26540         Old         NaN          NaN

# %%
import ast

x = df.iloc[2,5]

key_1 = 'ClientState'
key_2 = 'loam_amount'
key_3 = 'loan_period'

def array_parsing(key):
    value_list = []
    for i in range(len(df)):
        if 'null' in df.iloc[i,5]:
            df.iloc[i,5] = df.iloc[i,5].replace('null', 'None')
        else:
            pass
        element = ast.literal_eval(str(df.iloc[i,5]))
        if key in element:
            element = element.get(key)
            value_list.append(element)
        else:
            value_list.append(np.NaN)
    return value_list
        
df[key_1] = array_parsing(key_1)
df[key_2] = array_parsing(key_2)
df[key_3] = array_parsing(key_3)

df.head(4)
# Out:
#   Attributed Touch Type Attributed Touch Time         Install Time  \
# 0                 click   2022-12-25 23:58:24  2022-12-25 23:59:03
# 1                 click   2022-12-25 23:58:24  2022-12-25 23:59:03
# 2                 click   2022-12-25 23:56:18  2022-12-25 23:58:57
# 3                 click   2022-12-24 14:48:56  2022-12-24 14:51:06
#
#             Event Time          Event Name            Event Value  \
# 0  2022-12-25 23:59:31            af_login  {"ClientState":"New"}
# 1  2022-12-25 23:59:06  install_kreditomat  {"ClientState":"New"}
# 2  2022-12-25 23:59:00  install_kreditomat  {"ClientState":"New"}
# 3  2022-12-25 23:52:02            af_login  {"ClientState":"New"}
#
#    Event Revenue Event Revenue Currency  Event Revenue USD Event Source  \
# 0            NaN                    USD                NaN          SDK
# 1            NaN                    USD                NaN          SDK
# 2            NaN                    USD                NaN          SDK
# 3            NaN                    USD                NaN          SDK
#
#    Is Receipt Validated  Partner       Media Source      Channel  Keywords  \
# 0                   NaN      NaN  googleadwords_int   ACI_Search       NaN
# 1                   NaN      NaN  googleadwords_int   ACI_Search       NaN
# 2                   NaN      NaN  googleadwords_int   ACI_Search       NaN
# 3                   NaN      NaN  googleadwords_int  ACI_Display       NaN
#
#               Campaign   Campaign ID                    Adset      Adset ID  \
# 0  Instal G first open  1.833112e+10            Ремонт машины  1.431682e+11
# 1  Instal G first open  1.833112e+10            Ремонт машины  1.431682e+11
# 2  Instal G first open  1.833112e+10            Ремонт машины  1.431682e+11
# 3  Instal G first open  1.832725e+10  Вам одобрен микрокредит  1.402261e+11
#
#    Ad Ad ID          Ad Type       Site ID  Sub Site ID  Sub Param 1  \
# 0 NaN   NaN  ClickToDownload  GoogleSearch          NaN          NaN
# 1 NaN   NaN  ClickToDownload  GoogleSearch          NaN          NaN
# 2 NaN   NaN  ClickToDownload  GoogleSearch          NaN          NaN
# 3 NaN   NaN  ClickToDownload           NaN          NaN          NaN
#
#    Sub Param 2  Sub Param 3  Sub Param 4 Sub Param 5  Cost Model  Cost Value  \
# 0          NaN          NaN          NaN         NaN         NaN         NaN
# 1          NaN          NaN          NaN         NaN         NaN         NaN
# 2          NaN          NaN          NaN         NaN         NaN         NaN
# 3          NaN          NaN          NaN         NaN         NaN         NaN
#
#    Cost Currency  Contributor 1 Partner  Contributor 1 Media Source  \
# 0            NaN                    NaN                         NaN
# 1            NaN                    NaN                         NaN
# 2            NaN                    NaN                         NaN
# 3            NaN                    NaN                         NaN
#
#    Contributor 1 Campaign  Contributor 1 Touch Type  Contributor 1 Touch Time  \
# 0                     NaN                       NaN                       NaN
# 1                     NaN                       NaN                       NaN
# 2                     NaN                       NaN                       NaN
# 3                     NaN                       NaN                       NaN
#
#    Contributor 2 Partner  Contributor 2 Media Source  Contributor 2 Campaign  \
# 0                    NaN                         NaN                     NaN
# 1                    NaN                         NaN                     NaN
# 2                    NaN                         NaN                     NaN
# 3                    NaN                         NaN                     NaN
#
#    Contributor 2 Touch Type  Contributor 2 Touch Time  Contributor 3 Partner  \
# 0                       NaN                       NaN                    NaN
# 1                       NaN                       NaN                    NaN
# 2                       NaN                       NaN                    NaN
# 3                       NaN                       NaN                    NaN
#
#    Contributor 3 Media Source  Contributor 3 Campaign  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
#
#    Contributor 3 Touch Type  Contributor 3 Touch Time Region Country Code  \
# 0                       NaN                       NaN     AS           KZ
# 1                       NaN                       NaN     AS           KZ
# 2                       NaN                       NaN     AS           KZ
# 3                       NaN                       NaN     AS           KZ
#
#   State       City Postal Code   DMA              IP  WIFI    Operator  \
# 0   ALM   Boraldai      040708  None   95.82.127.210  True  Beeline KZ
# 1   ALM   Boraldai      040708  None   95.82.127.210  True  Beeline KZ
# 2   MAN  Zhanaozen      130202  None  194.39.108.132  True       Tele2
# 3   YUZ    Tasaryk      161113  None    95.82.92.122  True  Beeline KZ
#
#       Carrier Language                       AppsFlyer ID  \
# 0  Beeline KZ  русский  1672012738372-1934286870111148416
# 1  Beeline KZ  русский  1672012738372-1934286870111148416
# 2       Tele2  русский  1672012735462-2269115973090293949
# 3   BeelineKZ  русский  1671893461877-1527471239897430085
#
#                          Advertising ID  IDFA Android ID  Customer User ID  \
# 0  b02e2dc3-d600-4c5b-bd34-fc7b12173844   NaN        NaN               NaN
# 1  b02e2dc3-d600-4c5b-bd34-fc7b12173844   NaN        NaN               NaN
# 2  2ea82004-4ced-4cb8-948c-b9c2ad65abd3   NaN        NaN               NaN
# 3  a9d71650-41ad-4e12-8115-dac32bb64d6b   NaN        NaN               NaN
#
#    IMEI  IDFV Platform  Device Type OS Version App Version SDK Version  \
# 0   NaN   NaN  android          NaN         11     2.0.2.1      v6.2.0
# 1   NaN   NaN  android          NaN         11     2.0.2.1      v6.2.0
# 2   NaN   NaN  android          NaN         11     2.0.2.1      v6.2.0
# 3   NaN   NaN  android          NaN         12     2.0.2.1      v6.2.0
#
#                 App ID                                           App Name  \
# 0  com.payday.dozp.ref  Kreditomat.kz - кредит онлайн на карту и налич...
# 1  com.payday.dozp.ref  Kreditomat.kz - кредит онлайн на карту и налич...
# 2  com.payday.dozp.ref  Kreditomat.kz - кредит онлайн на карту и налич...
# 3  com.payday.dozp.ref  Kreditomat.kz - кредит онлайн на карту и налич...
#
#              Bundle ID  Is Retargeting  Retargeting Conversion Type  \
# 0  com.payday.dozp.ref           False                          NaN
# 1  com.payday.dozp.ref           False                          NaN
# 2  com.payday.dozp.ref           False                          NaN
# 3  com.payday.dozp.ref           False                          NaN
#
#   Attribution Lookback  Reengagement Window  Is Primary Attribution  \
# 0                  30d                  NaN                    True
# 1                  30d                  NaN                    True
# 2                  30d                  NaN                    True
# 3                  30d                  NaN                    True
#
#                                           User Agent HTTP Referrer  \
# 0  Dalvik/2.1.0 (Linux; U; Android 11; 21121119SG...           NaN
# 1  Dalvik/2.1.0 (Linux; U; Android 11; 21121119SG...           NaN
# 2  Dalvik/2.1.0 (Linux; U; Android 11; SM-A405FN ...           NaN
# 3  Dalvik/2.1.0 (Linux; U; Android 12; SM-A325F B...           NaN
#
#   Original URL  Blocked Reason Rule  Store Reinstall  Impressions  \
# 0          NaN                  NaN              NaN          NaN
# 1          NaN                  NaN              NaN          NaN
# 2          NaN                  NaN              NaN          NaN
# 3          NaN                  NaN              NaN          NaN
#
#   Conversion Type  Google Play Click Time Match Type  Mediation Network  OAID  \
# 0         install                     NaN        srn                NaN   NaN
# 1         install                     NaN        srn                NaN   NaN
# 2         install                     NaN        srn                NaN   NaN
# 3         install                     NaN        srn                NaN   NaN
#
#    Deeplink URL  Google Play Install Begin Time Campaign Type  Custom Data  \
# 0           NaN                             NaN            ua          NaN
# 1           NaN                             NaN            ua          NaN
# 2           NaN                             NaN            ua          NaN
# 3           NaN                             NaN            ua          NaN
#
#       Device Download Time        Device Model  Monetization Network  Segment  \
# 0  2022-12-25 23:58:45.000   Redmi::21121119SG                   NaN      NaN
# 1  2022-12-25 23:58:45.000   Redmi::21121119SG                   NaN      NaN
# 2  2022-12-25 23:57:00.000  samsung::SM-A405FN                   NaN      NaN
# 3  2022-12-24 14:50:55.000   samsung::SM-A325F                   NaN      NaN
#
#    Store Product Page Device Category ClientState loam_amount  loan_period
# 0                 NaN           phone         New         NaN          NaN
# 1                 NaN           phone         New         NaN          NaN
# 2                 NaN           phone         New         NaN          NaN
# 3                 NaN           phone         New         NaN          NaN

# %% [markdown]
# Сохраняем в таблицы уникальные Customer_ID по loan_rejected

# %%
# lr_event = df.loc[df['Event Name'] == 'loan_rejected']

# sorted = lr_event.sort_values('Customer User ID', ascending = True)
# lr_event = sorted.groupby('Customer User ID').first().reset_index()

# lr_event['Customer User ID'].to_excel(r'C:/Users/PC/Desktop/DataAnalytics/Events/loan_rej_customerID.xlsx', index=False)

# %% [markdown]
# Сохраняем в таблицы уникальные Customer_ID по loan_accepted

# %%
# accep_event = df.loc[df['Event Name'] == 'loan_accepted']

# sorted = accep_event.sort_values('Customer User ID', ascending = True)
# accep_event = sorted.groupby('Customer User ID').first().reset_index()

# accep_event['Customer User ID'].to_excel(r'C:/Users/PC/Desktop/DataAnalytics/Events/loan_accep_customerID.xlsx', index=False)

# %% [markdown]
# Получаем табилицу с Custumer ID и таблицу с Customer ID + Media Source

# %%
event_with_id = df_filter.loc[df_filter['Event Name'] == 'submit_loan_application']
                       # & (df['Event Name'] != 'af_login')
                       # & (df['Event Name'] != 'af_complete_registration')]

event_with_id[['Customer User ID', 'Media Source']].to_csv(r'C:/Users/PC/Desktop/DataAnalytics/Parser/cl_id_adv.csv', index=False, compression = None)

event_with_id = event_with_id.drop_duplicates(subset='Customer User ID')
event_with_id[['Install Time', 'Event Time', 'Customer User ID']].to_excel(r'C:/Users/PC/Desktop/DataAnalytics/Parser/cl_id_event_time.xlsx', index=False)

# %%
event_with_id[['Install Time', 'Event Time', 'Customer User ID']]
# Out:
#               Install Time           Event Time  Customer User ID
# 291    2022-12-25 18:39:29  2022-12-25 19:43:51          410999.0
# 569    2022-12-25 18:03:15  2022-12-25 18:06:55         1648161.0
# 629    2022-12-25 14:11:03  2022-12-25 17:45:21         1648047.0
# 677    2022-12-24 15:15:02  2022-12-25 17:29:10         1640547.0
# 911    2022-12-25 15:58:05  2022-12-25 16:09:17          895049.0
# ...                    ...                  ...               ...
# 26083  2022-10-29 08:06:09  2022-12-19 07:55:15         1291366.0
# 26108  2022-09-11 05:34:52  2022-12-19 07:45:25         1569810.0
# 26239  2022-09-10 22:30:24  2022-12-19 06:42:37         1570257.0
# 26265  2022-06-24 15:14:29  2022-12-19 06:28:00          619122.0
# 26535  2022-09-29 07:48:33  2022-12-19 03:18:51         1583630.0
#
# [154 rows x 3 columns]

# %%
# df[['Event Name', 'Event Value']].to_excel(r'C:/Users/PC/Desktop/DataAnalytics/Parser/events_in_arrays.xlsx', index=False)

# df.to_excel(r'C:/Users/PC/Desktop/DataAnalytics/Parser/events_in_arrays.xlsx', index=False)
