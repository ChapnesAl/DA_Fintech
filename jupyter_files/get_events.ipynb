# %% [markdown]
# Импорты и настройки

# %%
import requests
import pandas as pd
import numpy as np
import csv
import io

# %%
pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# Данные для для запроса

# %%
from_date = '2022-12-06'
to_date = '2022-12-06'


# ID Tez bol
app_id = 'com.tezbol.android'  # Tez bol android
token = 'Bearer eyJhbGciOiJBMjU2S1ciLCJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwidHlwIjoiSldUIiwiemlwIjoiREVGIn0.sEVLFBUJYOA0mqDnHXn26LmhHkk9brtcqEFUQ3ff28aHsMYW4IgcRQ.rHov5TPYLC05J7FU.kPdQbwAy_6DjqVQnHgOVPNh1hLwtSdKrSPIfwVBQx22brT5CfR0-QMnh_Gmz8zFvyKOYXY2JaIfKetASeZ2FM-6VxT8b7MmFESD-McDxnSa6x_HpAbAXT2D2oqK_x7uh7WWF4eVYQTgo6M5UL8qZyg_nBH1FC3BKUxo0NEnUWtdkxlk71GbcGtP7a0Ik1NNgh7f-uFfuDbh9Kx-RhV7m5Io14MuKoh9KW1SAo__N0g2yOk5_1KDgVhGSTPtyiI34FA1O-GB569ufliR4Yo2-i9mLoCWaiJHLltxE55rp39rqLgGQiSxBpAiG-c3gHB5n8cU9pqN4cvRpMMjOTxaAE6FZYM7WlTAx80Pmqy6yVXe3dBBH9UZjpFhc5aR84y-BYU0UnrODff2KT-EjTXap2nWI0ALZCC0LvX57FZk8ZQrlV1UG6tmx2_mXgQNkAuCYNzsgRajRUf3TjLNMEwVTpn-yCYbVo9YtKumwXu9bI-iHIKqPmvr8y466bA5_zYP7MQLG75jnKWbSr3VAf87VNA.VaZ4bKqcqdREmfgWC7bBDg'   


# #ID Kreditomat.KZ
# # app_id = 'id1392973739'   # kreditomat ios
# app_id = 'com.payday.dozp.ref'   # kreditomat android
# token = 'Bearer eyJhbGciOiJBMjU2S1ciLCJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwidHlwIjoiSldUIiwiemlwIjoiREVGIn0.sEVLFBUJYOA0mqDnHXn26LmhHkk9brtcqEFUQ3ff28aHsMYW4IgcRQ.rHov5TPYLC05J7FU.kPdQbwAy_6DjqVQnHgOVPNh1hLwtSdKrSPIfwVBQx22brT5CfR0-QMnh_Gmz8zFvyKOYXY2JaIfKetASeZ2FM-6VxT8b7MmFESD-McDxnSa6x_HpAbAXT2D2oqK_x7uh7WWF4eVYQTgo6M5UL8qZyg_nBH1FC3BKUxo0NEnUWtdkxlk71GbcGtP7a0Ik1NNgh7f-uFfuDbh9Kx-RhV7m5Io14MuKoh9KW1SAo__N0g2yOk5_1KDgVhGSTPtyiI34FA1O-GB569ufliR4Yo2-i9mLoCWaiJHLltxE55rp39rqLgGQiSxBpAiG-c3gHB5n8cU9pqN4cvRpMMjOTxaAE6FZYM7WlTAx80Pmqy6yVXe3dBBH9UZjpFhc5aR84y-BYU0UnrODff2KT-EjTXap2nWI0ALZCC0LvX57FZk8ZQrlV1UG6tmx2_mXgQNkAuCYNzsgRajRUf3TjLNMEwVTpn-yCYbVo9YtKumwXu9bI-iHIKqPmvr8y466bA5_zYP7MQLG75jnKWbSr3VAf87VNA.VaZ4bKqcqdREmfgWC7bBDg'   


# # #ID Creditomat.MD
# app_id = 'com.kreditomatmd.dozp.ref'   # MD kreditomat android
# token = 'Bearer eyJhbGciOiJBMjU2S1ciLCJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwidHlwIjoiSldUIiwiemlwIjoiREVGIn0.Hioi6Lb0C7wwtN6_9zoigB37ukPBlJdyF5R7G3DIncShFJtPNs9h9g.eqnAjdwd28XULE_-.IZsJsJuR5e-yVrcmWoDVe-DVURRjFEsQShgWwJ9unBkxAjz72n2IBrWecP7_pA9k6mV7br73JxgvWmPB6RNwTPcPOz0FbBQQIwX-xu2iD3udokHVk3XT5aP_aMHSWkADoeyJZyImnPf10-wCi8-nJ3vivzebPl6VCi5QQ-HorU5O8PLUq9LddE-0L7gfT6S0diMY7yW1HpAGHKethpI7abCwV9_yX88tptFHlaWV8zqsHysoqZmA-6tiyloCIoGOibFgk6Ix5tJYQaZkUFbvQf5IVdwoJVe-VeGEESnBedQA3UBbpAhHB1Hp1OZeZOBUpAOQHQRZkqNvy8y9QMMkr-5-_CS567ZAtUfh3ZbMcHau63e6fsQbbWQhDWeBZ6GDm5OuAIgyyJipAyEf7_6ozL0DS00wUYrhKH1vCF4kMid7VljHcVk2s_-2u79I2ttDsQtK3DGnbSYgsGkktkQDSKGCOlRLNNkpCnHp5bnhmLEbs-BpxwIlHW7PoNi3YQriaBLJrWt1Sn-T3j8N6lIwgFDG0A.sma12W1tpVnUAojhCVLMUA'

# %% [markdown]
# Запрос в Appsflyer

# %%
url = f"https://hq1.appsflyer.com/api/raw-data/export/app/com.tezbol.android/in_app_events_report/v5?from={from_date}&to={to_date}&event_name=&reattr=false&additional_fields=blocked_reason_rule,store_reinstall,impressions,conversion_type,gp_click_time,match_type,mediation_network,oaid,deeplink_url,gp_install_begin,campaign_type,custom_data,device_download_time,device_model,monetization_network,segment,store_product_page,device_category"

headers = {
    "accept": "text/csv",
    "authorization": token}

urlData = requests.get(url, headers=headers).content
df = pd.read_csv(io.StringIO(urlData.decode('utf-8')))

# %% [markdown]
# !!!!! убрал restricted !!!

# %%
df = df.loc[df['Media Source'] != 'restricted']

# %%
df.head(3)
# Out:
#   Attributed Touch Type Attributed Touch Time         Install Time  \
# 0                 click   2022-12-04 11:12:20  2022-12-06 23:55:06
# 1                 click   2022-12-05 11:46:08  2022-12-05 11:46:46
# 2                 click   2022-12-04 14:18:40  2022-12-06 22:48:40
#
#             Event Time  Event Name            Event Value  Event Revenue  \
# 0  2022-12-06 23:55:11  first_open                     {}            NaN
# 1  2022-12-06 22:56:28    af_login  {"ClientState":"Old"}            NaN
# 2  2022-12-06 22:48:50  first_open                     {}            NaN
#
#   Event Revenue Currency  Event Revenue USD Event Source  \
# 0                    USD                NaN          SDK
# 1                    USD                NaN          SDK
# 2                    USD                NaN          SDK
#
#    Is Receipt Validated  Partner       Media Source      Channel  Keywords  \
# 0                   NaN      NaN  googleadwords_int  ACI_Display       NaN
# 1                   NaN      NaN  googleadwords_int  ACI_Display       NaN
# 2                   NaN      NaN  googleadwords_int  ACI_Display       NaN
#
#               Campaign   Campaign ID               Adset      Adset ID  Ad  \
# 0  Instal - first open  1.906302e+10    Получи в 3 клика  1.432319e+11 NaN
# 1  Instal - first open  1.906810e+10  Получила за минуту  1.442988e+11 NaN
# 2  Instal - first open  1.906810e+10  Получила за минуту  1.442988e+11 NaN
#
#    Ad ID          Ad Type Site ID  Sub Site ID  Sub Param 1  Sub Param 2  \
# 0    NaN  ClickToDownload     NaN          NaN          NaN          NaN
# 1    NaN  ClickToDownload     NaN          NaN          NaN          NaN
# 2    NaN  ClickToDownload     NaN          NaN          NaN          NaN
#
#    Sub Param 3  Sub Param 4 Sub Param 5  Cost Model  Cost Value  \
# 0          NaN          NaN         NaN         NaN         NaN
# 1          NaN          NaN         NaN         NaN         NaN
# 2          NaN          NaN         NaN         NaN         NaN
#
#    Cost Currency  Contributor 1 Partner  Contributor 1 Media Source  \
# 0            NaN                    NaN                         NaN
# 1            NaN                    NaN                         NaN
# 2            NaN                    NaN                         NaN
#
#    Contributor 1 Campaign  Contributor 1 Touch Type  Contributor 1 Touch Time  \
# 0                     NaN                       NaN                       NaN
# 1                     NaN                       NaN                       NaN
# 2                     NaN                       NaN                       NaN
#
#    Contributor 2 Partner  Contributor 2 Media Source  Contributor 2 Campaign  \
# 0                    NaN                         NaN                     NaN
# 1                    NaN                         NaN                     NaN
# 2                    NaN                         NaN                     NaN
#
#    Contributor 2 Touch Type  Contributor 2 Touch Time  Contributor 3 Partner  \
# 0                       NaN                       NaN                    NaN
# 1                       NaN                       NaN                    NaN
# 2                       NaN                       NaN                    NaN
#
#    Contributor 3 Media Source  Contributor 3 Campaign  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
#
#    Contributor 3 Touch Type  Contributor 3 Touch Time Region Country Code  \
# 0                       NaN                       NaN     AS           KZ
# 1                       NaN                       NaN     AS           KZ
# 2                       NaN                       NaN     AS           KZ
#
#   State        City Postal Code   DMA             IP   WIFI    Operator  \
# 0   AKT      Aktobe         d02  None  176.122.85.91   True  Beeline KZ
# 1   YUZ     Kaitpas      160024  None  194.0.188.112  False  Beeline KZ
# 2   KZY  Kyzyl-Orda         n00  None  95.57.233.243   True  Beeline KZ
#
#       Carrier    Language                       AppsFlyer ID  \
# 0   BeelineKZ     русский  1670367354422-1994174133818166914
# 1  Beeline KZ  қазақ тілі  1670240804031-8902155094375818584
# 2  Beeline KZ     русский  1670366908718-5631805336075466281
#
#                          Advertising ID  IDFA  Android ID  Customer User ID  \
# 0  0a658109-ccda-4b93-a163-1a930583f74a   NaN         NaN               NaN
# 1  e0b81885-21bf-45c4-b527-ca5b0a42e357   NaN         NaN          116587.0
# 2  e34274b5-a02d-4877-bae9-b80047f2ad45   NaN         NaN               NaN
#
#    IMEI  IDFV Platform  Device Type OS Version App Version SDK Version  \
# 0   NaN   NaN  android          NaN         12      1.0.14      v6.2.0
# 1   NaN   NaN  android          NaN         11      1.0.13      v6.2.0
# 2   NaN   NaN  android          NaN         12      1.0.14      v6.2.0
#
#                App ID App Name           Bundle ID  Is Retargeting  \
# 0  com.tezbol.android  TEZ BOL  com.tezbol.android           False
# 1  com.tezbol.android  TEZ BOL  com.tezbol.android           False
# 2  com.tezbol.android  TEZ BOL  com.tezbol.android           False
#
#    Retargeting Conversion Type Attribution Lookback  Reengagement Window  \
# 0                          NaN                  30d                  NaN
# 1                          NaN                  30d                  NaN
# 2                          NaN                  30d                  NaN
#
#    Is Primary Attribution                                         User Agent  \
# 0                    True  Dalvik/2.1.0 (Linux; U; Android 12; SM-A325F B...
# 1                    True  Dalvik/2.1.0 (Linux; U; Android 11; SM-A505FN ...
# 2                    True  Dalvik/2.1.0 (Linux; U; Android 12; CPH2363 Bu...
#
#    HTTP Referrer  Original URL  Blocked Reason Rule  Store Reinstall  \
# 0            NaN           NaN                  NaN              NaN
# 1            NaN           NaN                  NaN              NaN
# 2            NaN           NaN                  NaN              NaN
#
#    Impressions Conversion Type  Google Play Click Time Match Type  \
# 0          NaN         install                     NaN        srn
# 1          NaN         install                     NaN        srn
# 2          NaN         install                     NaN        srn
#
#    Mediation Network  OAID  Deeplink URL  Google Play Install Begin Time  \
# 0                NaN   NaN           NaN                             NaN
# 1                NaN   NaN           NaN                             NaN
# 2                NaN   NaN           NaN                             NaN
#
#   Campaign Type  Custom Data     Device Download Time        Device Model  \
# 0            ua          NaN  2022-12-06 22:54:16.000   samsung::SM-A325F
# 1            ua          NaN  2022-12-05 11:39:19.000  samsung::SM-A505FN
# 2            ua          NaN  2022-12-06 22:47:57.000       OPPO::CPH2363
#
#    Monetization Network  Segment  Store Product Page Device Category  \
# 0                   NaN      NaN                 NaN           phone
# 1                   NaN      NaN                 NaN           phone
# 2                   NaN      NaN                 NaN           phone
#
#   ClientState loam_amount  loan_period
# 0         NaN         NaN          NaN
# 1         Old         NaN          NaN
# 2         NaN         NaN          NaN

# %%
# for i in df[["Event Name","Event Value"]].to_list():
#     print(i)
    
# for i in df['Event Name'].to_list():
#     print(i)

df[["Event Name","Event Value"]]
# Out:
#                    Event Name  \
# 0                  first_open
# 1                    af_login
# 2                  first_open
# 3                    af_login
# 4                    af_login
# ...                       ...
# 3050       install_kreditomat
# 3051                 af_login
# 3052            loan_rejected
# 3053  submit_loan_application
# 3054                 af_login
#
#                                             Event Value
# 0                                                    {}
# 1                                 {"ClientState":"Old"}
# 2                                                    {}
# 3                                 {"ClientState":"Old"}
# 4                                 {"ClientState":"Old"}
# ...                                                 ...
# 3050                              {"ClientState":"New"}
# 3051                              {"ClientState":"Old"}
# 3052                        {"loan_client_id":"111844"}
# 3053  {"loan_client_id":"111844","loam_amount":6000,...
# 3054                              {"ClientState":"Old"}
#
# [3050 rows x 2 columns]

# %%
# import ast
# for i in df["Event Value"].to_list():
#     print(i)

type(ast.literal_eval(df.iloc[1,5]))
# Out:
# dict

# %%
import ast

for i in range(len(df)):
    # print(df.iloc[i,5])
    if 'null' in df.iloc[i,5]:
        df.iloc[i,5] = df.iloc[i,5].replace('null', 'None')
    else:
        pass
    element = ast.literal_eval(str(df.iloc[i,5]))
    print(element)
# Out:
# {}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '113953'}
# {'loan_client_id': '113953', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117398'}
# {'loan_client_id': '117398', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117314', 'af_price': 6000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117314', 'af_price': 2000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117401', 'af_price': 2000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117401', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117401'}
# {}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117398'}
# {'loan_client_id': '117398', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117390', 'af_price': 5000, 'loan_period': 8}
# {'af_customer_user_id': '117390'}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117386', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117386'}
# {}
# {'ClientState': 'Old'}
# {'loan_client_id': '113726', 'loam_amount': 2000, 'loan_period': 8}
# {'loan_client_id': '113726'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117382'}
# {}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117330', 'af_price': 5000, 'loan_period': 10}
# {}
# {'af_customer_user_id': '11877'}
# {}
# {'af_customer_user_id': '117380'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '95592', 'af_price': 6000, 'loan_period': 10}
# {}
# {'loan_client_id': '116627', 'loam_amount': 6000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '116627'}
# {'loan_client_id': '116627', 'loam_amount': 1000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '113820'}
# {'loan_client_id': '113820', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117039'}
# {'loan_client_id': '117039', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '114112'}
# {'loan_client_id': '114112', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '72893', 'af_price': 6000, 'loan_period': 10}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '59519', 'af_price': 6000, 'loan_period': 10}
# {'loan_client_id': '113343', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '113343'}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117354'}
# {'af_customer_user_id': '117354'}
# {'af_currency': 'KZT', 'af_customer_user_id': '117354', 'af_price': '5000', 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117361', 'af_price': 5000, 'loan_period': 10}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 5000, 'loan_period': 8}
# {'af_customer_user_id': '117361'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117354', 'af_price': 5000, 'loan_period': 8}
# {}
# {'af_customer_user_id': '117354'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117360', 'af_price': 5000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '114197', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117360'}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '114197', 'af_price': 5000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117354', 'af_price': 6000, 'loan_period': 10}
# {'af_customer_user_id': '117354'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117356', 'af_price': 2000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117356', 'af_price': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 6000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117354', 'af_price': 6000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117356', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117356'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117352', 'af_price': 5000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117354', 'af_price': 5000, 'loan_period': 8}
# {'af_customer_user_id': '117354'}
# {}
# {}
# {}
# {'af_customer_user_id': '117352'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117345', 'af_price': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {'loan_client_id': '116968', 'loam_amount': '6000', 'loan_period': 10}
# {'loan_client_id': '112746', 'loam_amount': '20000', 'loan_period': 12}
# {'loan_client_id': '116968', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '116968', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '112746', 'loam_amount': 20000, 'loan_period': 12}
# {'loan_client_id': '27640', 'loam_amount': 33000, 'loan_period': 12}
# {'loan_client_id': '27640'}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '43338'}
# {'af_customer_user_id': '43338'}
# {'af_currency': 'KZT', 'af_customer_user_id': '43338', 'af_price': '56000', 'loan_period': 10}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 56000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.02, 'af_customer_user_id': '43338', 'af_price': 56000, 'loan_period': 10}
# {'af_customer_user_id': '117347'}
# {'ClientState': 'New'}
# {'af_customer_user_id': '43338'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117346', 'loam_amount': 1000, 'loan_period': 8}
# {'loan_client_id': '117346', 'loam_amount': 2000, 'loan_period': 8}
# {'loan_client_id': '117346'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117346', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '117346'}
# {'af_customer_user_id': '43338'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'af_customer_user_id': '43338'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117345', 'af_price': 6000, 'loan_period': 10}
# {}
# {'loan_client_id': '117344'}
# {'loan_client_id': '117344', 'loam_amount': 0, 'loan_period': 0}
# {'af_customer_user_id': '43338'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '78286', 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117345', 'af_price': 5000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117345'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '115509', 'af_price': 1000, 'loan_period': 10}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 1000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '101523', 'af_price': 1000, 'loan_period': 10}
# {'af_customer_user_id': '101523'}
# {'af_customer_user_id': '11877'}
# {'af_currency': 'KZT', 'af_revenue': -12000, 'af_customer_user_id': '11877', 'af_price': 6000, 'loan_period': -289, 'af_order_id': None, 'loan_id': None}
# {'af_customer_user_id': '11877'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '59390', 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '101523', 'af_price': 1000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117330', 'af_price': 5000, 'loan_period': 10}
# {}
# {'loan_client_id': '116645'}
# {'loan_client_id': '116645', 'loam_amount': 6000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117340', 'af_price': 6000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '101523', 'af_price': 1000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117330', 'af_price': 5000, 'loan_period': 10}
# {'ClientState': 'New'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '98082', 'af_price': 3000, 'loan_period': 9}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '78286', 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117342', 'af_price': 6000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117342', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117342'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '98082', 'af_price': 2000, 'loan_period': 8}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117340', 'af_price': 5000, 'loan_period': 10}
# {}
# {'af_customer_user_id': '117340'}
# {}
# {'af_customer_user_id': '79585'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '101404', 'af_price': 4000, 'loan_period': 10}
# {'af_currency': 'KZT', 'af_revenue': -53720, 'af_customer_user_id': '79585', 'af_price': 34000, 'loan_period': -60, 'af_order_id': None, 'loan_id': None}
# {'af_customer_user_id': '79585'}
# {}
# {}
# {'af_customer_user_id': '43338'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117337', 'af_price': 5000, 'loan_period': 8}
# {'af_customer_user_id': '43338'}
# {'af_customer_user_id': '43338'}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117337'}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117336', 'af_price': 2000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117336', 'af_price': 5000, 'loan_period': 8}
# {'af_customer_user_id': '117336'}
# {}
# {'ClientState': 'Old'}
# {'loan_client_id': '38129'}
# {'loan_client_id': '38129', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117333', 'af_price': 5000, 'loan_period': 10}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117331'}
# {'loan_client_id': '117331', 'loam_amount': 13000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '117331', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117333', 'af_price': 5000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117333'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117330', 'af_price': 5000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {}
# {'af_customer_user_id': '117330'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117324'}
# {'af_currency': 'KZT', 'af_customer_user_id': '117324', 'af_price': '6000', 'loan_period': 10}
# {}
# {'af_customer_user_id': '11877'}
# {'af_currency': 'KZT', 'af_revenue': -12000, 'af_customer_user_id': '11877', 'af_price': 6000, 'loan_period': -289, 'af_order_id': None, 'loan_id': None}
# {'af_customer_user_id': '11877'}
# {'af_customer_user_id': '11877'}
# {'af_currency': 'KZT', 'loan_percent': 0.02, 'af_customer_user_id': '52716', 'af_price': 13000, 'loan_period': 12}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117326', 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 6000, 'loan_period': 10}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117324', 'af_price': 6000, 'loan_period': 10}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117326', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117326'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117324', 'af_price': 5000, 'loan_period': 10}
# {}
# {'af_customer_user_id': '117324'}
# {}
# {}
# {}
# {}
# {}
# {'ClientState': 'Old'}
# {'loan_client_id': '115272'}
# {'loan_client_id': '115272', 'loam_amount': 6000, 'loan_period': 8}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116587', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '116587'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116065'}
# {'loan_client_id': '116065', 'loam_amount': 6000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.02, 'af_customer_user_id': '74343', 'af_price': 8000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.02, 'af_customer_user_id': '74343', 'af_price': 8000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.02, 'af_customer_user_id': '74343', 'af_price': 8000, 'loan_period': 12}
# {'loan_client_id': '114133'}
# {'loan_client_id': '114133', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.02, 'af_customer_user_id': '74343', 'af_price': 10000, 'loan_period': 12}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117314', 'af_price': 1000, 'loan_period': 8}
# {'af_customer_user_id': '117313'}
# {'af_currency': 'KZT', 'af_customer_user_id': '117313', 'af_price': '7000', 'loan_period': 12}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117314', 'af_price': 2000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117314', 'af_price': 3000, 'loan_period': 10}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 7000, 'loan_period': 12}
# {'af_currency': 'KZT', 'loan_percent': 0.02, 'af_customer_user_id': '117313', 'af_price': 7000, 'loan_period': 12}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117314', 'af_price': 5000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117314'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117313', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117313'}
# {}
# {}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116100'}
# {'loan_client_id': '116100', 'loam_amount': 0, 'loan_period': 0}
# {}
# {}
# {'loan_client_id': '117310', 'loam_amount': 5000, 'loan_period': 8}
# {'loan_client_id': '117310'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117310'}
# {'loan_client_id': '117310', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117252', 'af_price': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 6000, 'loan_period': 10}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117309'}
# {'loan_client_id': '117309', 'loam_amount': 6000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '117309', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '117309'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117308', 'af_price': 5000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117308', 'af_price': 5000, 'loan_period': 10}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117252', 'af_price': 6000, 'loan_period': 10}
# {'af_customer_user_id': '117308'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.02, 'af_customer_user_id': '117307', 'af_price': 10000, 'loan_period': 12}
# {}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117306', 'af_price': 6000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117306', 'af_price': 3000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117306', 'af_price': 6000, 'loan_period': 10}
# {'ClientState': 'New'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117307', 'af_price': 5000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117306', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117307'}
# {'af_customer_user_id': '117306'}
# {'ClientState': 'New'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '73121', 'af_price': 6000, 'loan_period': 10}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '73121', 'af_price': 6000, 'loan_period': 8}
# {}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117304', 'af_price': 5000, 'loan_period': 9}
# {}
# {'af_customer_user_id': '117304'}
# {'ClientState': 'New'}
# {}
# {'ClientState': 'New'}
# {'af_customer_user_id': '117300'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {}
# {'loan_client_id': '116757'}
# {'loan_client_id': '116757', 'loam_amount': 2000, 'loan_period': 8}
# {'loan_client_id': '116757', 'loam_amount': 2000, 'loan_period': 8}
# {'loan_client_id': '116757'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116757'}
# {'loan_client_id': '116757', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {}
# {'af_customer_user_id': '117298'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117295', 'af_price': 6000, 'loan_period': 10}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '79239', 'af_price': 2000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117295', 'af_price': 5000, 'loan_period': 10}
# {}
# {'loan_client_id': '116328', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '116328'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '98572', 'af_price': 6000, 'loan_period': 10}
# {'af_customer_user_id': '117295'}
# {'ClientState': 'Old'}
# {}
# {}
# {'loan_client_id': '116954'}
# {'loan_client_id': '116954', 'loam_amount': 5000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117293', 'af_price': 2000, 'loan_period': 8}
# {'loan_client_id': '116954'}
# {'loan_client_id': '116954', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '116954'}
# {'loan_client_id': '116954', 'loam_amount': 3000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {'loan_client_id': '116954'}
# {'loan_client_id': '116954', 'loam_amount': 3000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117293', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '47051'}
# {'af_customer_user_id': '117293'}
# {}
# {}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117289', 'af_price': 6000, 'loan_period': 8}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117289', 'af_price': 6000, 'loan_period': 8}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117289', 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117290', 'af_price': 1000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117287', 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117287', 'af_price': 6000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117290', 'af_price': 5000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117257', 'af_price': 2000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117289', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117289'}
# {'af_customer_user_id': '117290'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117257', 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117287', 'af_price': 5000, 'loan_period': 8}
# {}
# {'af_customer_user_id': '117287'}
# {}
# {'af_customer_user_id': '55249'}
# {}
# {'af_currency': 'KZT', 'af_revenue': -12000, 'af_customer_user_id': '55249', 'af_price': 6000, 'loan_period': -159, 'af_order_id': None, 'loan_id': None}
# {'af_customer_user_id': '55249'}
# {}
# {'af_customer_user_id': '55249'}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117285'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117284', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117284'}
# {}
# {}
# {'ClientState': 'Old'}
# {'loan_client_id': '117276'}
# {'loan_client_id': '117276', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '117276'}
# {'loan_client_id': '117276', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '117276'}
# {'loan_client_id': '117276', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '117276'}
# {'loan_client_id': '117276', 'loam_amount': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 5000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '117276', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '117276'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117276'}
# {'loan_client_id': '117276', 'loam_amount': 0, 'loan_period': 0}
# {'af_customer_user_id': '55249'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117280', 'af_price': 5000, 'loan_period': 10}
# {'af_currency': 'KZT', 'af_revenue': -12000, 'af_customer_user_id': '55249', 'af_price': 6000, 'loan_period': -159, 'af_order_id': None, 'loan_id': None}
# {'af_customer_user_id': '55249'}
# {'af_customer_user_id': '55249'}
# {'af_customer_user_id': '117280'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117273', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117273'}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 5000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117273', 'af_price': 5000, 'loan_period': 10}
# {}
# {'af_customer_user_id': '19207'}
# {'af_currency': 'KZT', 'af_revenue': -26000, 'af_customer_user_id': '19207', 'af_price': 13000, 'loan_period': -266, 'af_order_id': None, 'loan_id': None}
# {'af_customer_user_id': '19207'}
# {'af_customer_user_id': '19207'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117273', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117273'}
# {'ClientState': 'New'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '70185', 'af_price': 2000, 'loan_period': 8}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '115806'}
# {'loan_client_id': '115806', 'loam_amount': 4000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117252', 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117267', 'af_price': 5000, 'loan_period': 10}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '70185', 'af_price': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117269'}
# {'af_customer_user_id': '70185'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117267', 'af_price': 5000, 'loan_period': 10}
# {}
# {'af_customer_user_id': '117267'}
# {}
# {}
# {}
# {}
# {}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117252', 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117252', 'af_price': 6000, 'loan_period': 10}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117257', 'af_price': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '117256', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '117256'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117257', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117257'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 6000, 'loan_period': 10}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117252', 'af_price': 6000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117252', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117252'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117245'}
# {'loan_client_id': '117245', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117245'}
# {'loan_client_id': '117245', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '88145', 'af_price': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '117217', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '117217'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117217'}
# {'loan_client_id': '117217', 'loam_amount': 0, 'loan_period': 0}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '88145', 'af_price': 6000, 'loan_period': 10}
# {'ClientState': 'New'}
# {'af_customer_user_id': '88145'}
# {}
# {}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '44064', 'af_price': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '102169'}
# {'loan_client_id': '102169', 'loam_amount': 6000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117237', 'af_price': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '44064', 'af_price': 6000, 'loan_period': 10}
# {}
# {'af_customer_user_id': '44064'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117237', 'af_price': 5000, 'loan_period': 8}
# {'af_customer_user_id': '117238'}
# {'af_customer_user_id': '117237'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '81717', 'af_price': 6000, 'loan_period': 10}
# {'af_customer_user_id': '81717'}
# {'ClientState': 'Old'}
# {}
# {}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '101404', 'af_price': 2000, 'loan_period': 8}
# {}
# {'ClientState': 'New'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117228', 'af_price': 5000, 'loan_period': 10}
# {'af_customer_user_id': '117228'}
# {}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '59519', 'af_price': 2000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '59519', 'af_price': 5000, 'loan_period': 10}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117218'}
# {'loan_client_id': '113880', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '113880'}
# {'loan_client_id': '113880', 'loam_amount': 4000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '113880'}
# {'loan_client_id': '113880', 'loam_amount': 6000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117216', 'af_price': 5000, 'loan_period': 8}
# {}
# {'af_customer_user_id': '117216'}
# {'loan_client_id': '117070'}
# {'loan_client_id': '117070', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '117204'}
# {'loan_client_id': '117204', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'loan_client_id': '117070'}
# {'loan_client_id': '117070', 'loam_amount': 0, 'loan_period': 0}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116964'}
# {'loan_client_id': '116964', 'loam_amount': 4000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '116964'}
# {'loan_client_id': '116964', 'loam_amount': 0, 'loan_period': 0}
# {'af_customer_user_id': '94809'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '90710'}
# {'loan_client_id': '90710', 'loam_amount': 5000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '29809', 'af_price': 5000, 'loan_period': 10}
# {}
# {}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117203', 'af_price': 2000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117202', 'af_price': 5000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117202', 'af_price': 2000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117203', 'af_price': 5000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'af_customer_user_id': '117203'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117202', 'af_price': 5000, 'loan_period': 8}
# {'af_customer_user_id': '117202'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '37848', 'af_price': 5000, 'loan_period': 9}
# {}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '37848', 'af_price': 6000, 'loan_period': 9}
# {}
# {}
# {}
# {'ClientState': 'Old'}
# {'loan_client_id': '111770', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '111770'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117196', 'af_price': 5000, 'loan_period': 8}
# {'af_customer_user_id': '117196'}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '60406', 'af_price': 6000, 'loan_period': 10}
# {'af_customer_user_id': '60406'}
# {}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'af_currency': 'KZT', 'loan_percent': 0.02, 'af_customer_user_id': '59454', 'af_price': 15000, 'loan_period': 12}
# {'af_currency': 'KZT', 'loan_percent': 0.02, 'af_customer_user_id': '59454', 'af_price': 15000, 'loan_period': 12}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '114888'}
# {'loan_client_id': '114888', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117184'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117180', 'af_price': 1000, 'loan_period': 10}
# {'af_currency': 'KZT', 'af_customer_user_id': 0, 'af_price': 13000, 'loan_period': 10}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117178', 'af_price': 13000, 'loan_period': 10}
# {'af_customer_user_id': '117180'}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117177', 'loam_amount': 2000, 'loan_period': 8}
# {'loan_client_id': '117177'}
# {'loan_client_id': '117177', 'loam_amount': 6000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117178', 'af_price': 5000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117178'}
# {'loan_client_id': '112746', 'loam_amount': '23000', 'loan_period': 12}
# {'ClientState': 'Old'}
# {'loan_client_id': '112746', 'loam_amount': 23000, 'loan_period': 12}
# {'ClientState': 'Old'}
# {'loan_client_id': '117177'}
# {'loan_client_id': '117177', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '37242', 'af_price': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117167', 'af_price': 5000, 'loan_period': 10}
# {'submit_registration': 'kreditomat'}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '37242', 'af_price': 6000, 'loan_period': 10}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117017'}
# {'loan_client_id': '117017', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117169'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117169', 'loam_amount': 5000, 'loan_period': 10}
# {'loan_client_id': '117168', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117169', 'loam_amount': 0, 'loan_period': 0}
# {}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '117167', 'af_price': 5000, 'loan_period': 10}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '117167'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {}
# {'ClientState': 'Old'}
# {}
# {}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '111088', 'af_price': 2000, 'loan_period': 8}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '111088', 'af_price': 1000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'af_currency': 'KZT', 'loan_percent': 0.023, 'af_customer_user_id': '111088', 'af_price': 6000, 'loan_period': 10}
# {'loan_client_id': '34360', 'loam_amount': 3000, 'loan_period': 12}
# {'ClientState': 'Old'}
# {}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117165', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '117165'}
# {'loan_client_id': '34360'}
# {'ClientState': 'Old'}
# {'loan_client_id': '34360', 'loam_amount': 3000, 'loan_period': 12}
# {'ClientState': 'Old'}
# {'loan_client_id': '34360', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'loan_client_id': '34051', 'loam_amount': 10000, 'loan_period': 8}
# {'loan_client_id': '34051', 'loam_amount': 14000, 'loan_period': 8}
# {'loan_client_id': '34051'}
# {'ClientState': 'Old'}
# {'loan_client_id': '34051', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'loan_client_id': '34051'}
# {'ClientState': 'Old'}
# {'af_customer_user_id': '94809'}
# {'af_customer_user_id': '94809'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'af_currency': 'KZT', 'af_revenue': -28500, 'af_customer_user_id': '94809', 'af_price': 19000, 'loan_period': -43, 'af_order_id': None, 'loan_id': None}
# {'af_customer_user_id': '94809'}
# {'ClientState': 'Old'}
# {}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117164'}
# {'loan_client_id': '117164', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'loan_client_id': '117162'}
# {'loan_client_id': '117162', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '117162'}
# {'loan_client_id': '117162', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '114198'}
# {'loan_client_id': '114198', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '55470'}
# {'loan_client_id': '55470', 'loam_amount': 19000, 'loan_period': 12}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '93675'}
# {'loan_client_id': '93675', 'loam_amount': 1000, 'loan_period': 8}
# {'loan_client_id': '93675', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '93675'}
# {'loan_client_id': '93675', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '115591', 'loam_amount': 6000, 'loan_period': 8}
# {'loan_client_id': '115591'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '55470', 'loam_amount': 19000, 'loan_period': 12}
# {'loan_client_id': '55470'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117148'}
# {'loan_client_id': '117148', 'loam_amount': 1000, 'loan_period': 8}
# {'loan_client_id': '117148'}
# {'loan_client_id': '117148', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '117148'}
# {'loan_client_id': '117148', 'loam_amount': 3000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '117148', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '117148'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'loan_client_id': '114198', 'loam_amount': 2000, 'loan_period': 8}
# {'loan_client_id': '114198'}
# {'ClientState': 'Old'}
# {'loan_client_id': '114198'}
# {'loan_client_id': '114198', 'loam_amount': 6000, 'loan_period': 8}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117141'}
# {'loan_client_id': '117141', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '117141'}
# {'loan_client_id': '117141', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117140'}
# {'loan_client_id': '117140', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116556'}
# {'loan_client_id': '116556', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116556', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '116556'}
# {'ClientState': 'New'}
# {'loan_client_id': '117137', 'loam_amount': '6000', 'loan_period': 10}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117137', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '117137', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'loan_client_id': '117135'}
# {'loan_client_id': '117135', 'loam_amount': 1000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117135'}
# {'loan_client_id': '117135', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '117135'}
# {'loan_client_id': '117135', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'loan_client_id': '117135'}
# {'loan_client_id': '117135', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '117135'}
# {'loan_client_id': '117135', 'loam_amount': 3000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '70789'}
# {'loan_client_id': '70789', 'loam_amount': 1000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'loan_client_id': '70789'}
# {'loan_client_id': '70789', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117135'}
# {'loan_client_id': '117135', 'loam_amount': 3000, 'loan_period': 9}
# {'loan_client_id': '117136'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117136', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'loan_client_id': '117135'}
# {'loan_client_id': '117135', 'loam_amount': 4000, 'loan_period': 10}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117135'}
# {'loan_client_id': '117135', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117135'}
# {'loan_client_id': '117135', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '115591'}
# {'loan_client_id': '115591', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116717', 'loam_amount': 13000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'loan_client_id': '116717', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117133', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '117133'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'loan_client_id': '117133', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '117133'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '113808'}
# {'loan_client_id': '113808', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117128'}
# {'loan_client_id': '117128', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '117126'}
# {'loan_client_id': '117126', 'loam_amount': 0, 'loan_period': 0}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '55470'}
# {'loan_client_id': '55470', 'loam_amount': 22000, 'loan_period': 12}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117124'}
# {'loan_client_id': '117124', 'loam_amount': 4000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117123'}
# {'loan_client_id': '117124'}
# {'loan_client_id': '117123', 'loam_amount': 6000, 'loan_period': 8}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117123'}
# {'loan_client_id': '117123', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '117124', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117123'}
# {'submit_registration': 'kreditomat'}
# {'loan_client_id': '117123', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117120'}
# {'loan_client_id': '117120', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'loan_client_id': '117116', 'loam_amount': '13000', 'loan_period': 10}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117118'}
# {'loan_client_id': '117118', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '117118'}
# {'loan_client_id': '117118', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '117116', 'loam_amount': 13000, 'loan_period': 10}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117116', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'loan_client_id': '117117', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '117117'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '85053'}
# {'loan_client_id': '85053', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '117115', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '117115'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'loan_client_id': '117114', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '117114'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# ...
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'loan_client_id': '69905'}
# {'loan_client_id': '69905', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'loan_client_id': '113439'}
# {'loan_client_id': '113439', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '112702'}
# {'loan_client_id': '112702', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '38129'}
# {'loan_client_id': '38129', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116916'}
# {'loan_client_id': '116916', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '116916', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '116916'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116916'}
# {'loan_client_id': '116916', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116913', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '116913'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116913'}
# {'loan_client_id': '116913', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116912'}
# {'loan_client_id': '116912', 'loam_amount': 6000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '116912', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '116912'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'loan_client_id': '116909', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '116909'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116904', 'loam_amount': 1000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '116904'}
# {'loan_client_id': '116904', 'loam_amount': 3000, 'loan_period': 8}
# {'loan_client_id': '116905'}
# {'loan_client_id': '116905', 'loam_amount': 6000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '116905'}
# {'loan_client_id': '116905', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116904'}
# {'loan_client_id': '116904', 'loam_amount': 6000, 'loan_period': 8}
# {'loan_client_id': '116905'}
# {'ClientState': 'New'}
# {'loan_client_id': '116905', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116904'}
# {'loan_client_id': '116904', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116902', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '116902'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'submit_registration': 'kreditomat'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116896'}
# {'loan_client_id': '116896', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116897'}
# {'loan_client_id': '116897', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '116897'}
# {'loan_client_id': '116897', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116894'}
# {'loan_client_id': '116894', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'loan_client_id': '116892', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '116892'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'loan_client_id': '72200', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '72200'}
# {'loan_client_id': '72200', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '113686'}
# {'loan_client_id': '113686', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '115664'}
# {'loan_client_id': '115664', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'loan_client_id': '115613'}
# {'loan_client_id': '115613', 'loam_amount': 2000, 'loan_period': 10}
# {'loan_client_id': '115613', 'loam_amount': 2000, 'loan_period': 8}
# {'loan_client_id': '115613'}
# {'ClientState': 'Old'}
# {'loan_client_id': '115613', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '115613'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '115923'}
# {'loan_client_id': '115923', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'loan_client_id': '115624', 'loam_amount': '2000', 'loan_period': 8}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'loan_client_id': '116888'}
# {'loan_client_id': '116888', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '116888'}
# {'loan_client_id': '116888', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'loan_client_id': '115624', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116885'}
# {'loan_client_id': '116885', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116880', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '116880'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116881'}
# {'loan_client_id': '116881', 'loam_amount': 5000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'loan_client_id': '116881'}
# {'loan_client_id': '116881', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'loan_client_id': '116853', 'loam_amount': 2000, 'loan_period': 8}
# {'loan_client_id': '116853'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'loan_client_id': '116853', 'loam_amount': 2000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'loan_client_id': '116853', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '116853'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'loan_client_id': '116876', 'loam_amount': 6000, 'loan_period': 8}
# {'loan_client_id': '116876'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116876'}
# {'loan_client_id': '116876', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'loan_client_id': '106770'}
# {'loan_client_id': '106770', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116873'}
# {'loan_client_id': '116873', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116519', 'loam_amount': 6000, 'loan_period': 8}
# {'loan_client_id': '116519'}
# {'ClientState': 'Old'}
# {'loan_client_id': '59917', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '59917'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116519', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '116519'}
# {'loan_client_id': '116868'}
# {'loan_client_id': '116868', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116867', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '116867'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116867', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '116867'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'loan_client_id': '104211', 'loam_amount': 6000, 'loan_period': 10}
# {'loan_client_id': '104211'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116861', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '116861'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'loan_client_id': '113061'}
# {'loan_client_id': '113061', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'loan_client_id': '115668'}
# {'loan_client_id': '115668', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'loan_client_id': '115767'}
# {'loan_client_id': '115767', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '72475'}
# {'loan_client_id': '72475', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'loan_client_id': '72475'}
# {'loan_client_id': '72475', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '115806'}
# {'loan_client_id': '115806', 'loam_amount': 5000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116853', 'loam_amount': 2000, 'loan_period': 10}
# {'loan_client_id': '116853'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116853', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '116853'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116596'}
# {'loan_client_id': '116596', 'loam_amount': 3000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '116596'}
# {'loan_client_id': '116596', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '114198'}
# {'loan_client_id': '114198', 'loam_amount': 6000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116287', 'loam_amount': 10000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116287'}
# {'loan_client_id': '116287', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'loan_client_id': '27640'}
# {'loan_client_id': '27640', 'loam_amount': 31000, 'loan_period': 12}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '68237'}
# {'loan_client_id': '68237', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116846'}
# {'loan_client_id': '116846', 'loam_amount': 1000, 'loan_period': 8}
# {'loan_client_id': '116846', 'loam_amount': 2000, 'loan_period': 8}
# {'ClientState': 'Old'}
# {'loan_client_id': '116846'}
# {'loan_client_id': '116846', 'loam_amount': 0, 'loan_period': 0}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '116845', 'loam_amount': 0, 'loan_period': 0}
# {'loan_client_id': '116845'}
# {'ClientState': 'Old'}
# {'submit_registration': 'kreditomat'}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '82026'}
# {'loan_client_id': '82026', 'loam_amount': 10000, 'loan_period': 12}
# {'ClientState': 'Old'}
# {'ClientState': 'Old'}
# {'ClientState': 'New'}
# {'ClientState': 'New'}
# {'ClientState': 'Old'}
# {'loan_client_id': '111844'}
# {'loan_client_id': '111844', 'loam_amount': 6000, 'loan_period': 10}
# {'ClientState': 'Old'}

# %%
df.tail(5)
# Out:
#      Attributed Touch Type Attributed Touch Time         Install Time  \
# 3050                 click   2022-12-04 14:58:27  2022-12-04 14:58:40
# 3051                 click   2022-12-03 21:55:28  2022-12-05 01:49:23
# 3052                 click   2022-12-03 21:55:28  2022-12-05 01:49:23
# 3053                 click   2022-12-03 21:55:28  2022-12-05 01:49:23
# 3054                 click   2022-12-03 21:55:28  2022-12-05 01:49:23
#
#                Event Time               Event Name  \
# 3050  2022-12-06 00:19:00       install_kreditomat
# 3051  2022-12-06 00:15:24                 af_login
# 3052  2022-12-06 00:15:17            loan_rejected
# 3053  2022-12-06 00:15:16  submit_loan_application
# 3054  2022-12-06 00:14:06                 af_login
#
#                                             Event Value  Event Revenue  \
# 3050                              {"ClientState":"New"}            NaN
# 3051                              {"ClientState":"Old"}            NaN
# 3052                        {"loan_client_id":"111844"}            NaN
# 3053  {"loan_client_id":"111844","loam_amount":6000,...            NaN
# 3054                              {"ClientState":"Old"}            NaN
#
#      Event Revenue Currency  Event Revenue USD Event Source  \
# 3050                    USD                NaN          SDK
# 3051                    USD                NaN          SDK
# 3052                    USD                NaN          SDK
# 3053                    USD                NaN          SDK
# 3054                    USD                NaN          SDK
#
#       Is Receipt Validated  Partner       Media Source      Channel  Keywords  \
# 3050                   NaN      NaN  googleadwords_int  ACI_Display       NaN
# 3051                   NaN      NaN  googleadwords_int  ACI_Display       NaN
# 3052                   NaN      NaN  googleadwords_int  ACI_Display       NaN
# 3053                   NaN      NaN  googleadwords_int  ACI_Display       NaN
# 3054                   NaN      NaN  googleadwords_int  ACI_Display       NaN
#
#                  Campaign   Campaign ID                Adset      Adset ID  \
# 3050  Instal - first open  1.906302e+10   Получила за минуту  1.391446e+11
# 3051  Instal - first open  1.907017e+10  Срочно нужны деньги  1.443061e+11
# 3052  Instal - first open  1.907017e+10  Срочно нужны деньги  1.443061e+11
# 3053  Instal - first open  1.907017e+10  Срочно нужны деньги  1.443061e+11
# 3054  Instal - first open  1.907017e+10  Срочно нужны деньги  1.443061e+11
#
#       Ad  Ad ID          Ad Type Site ID  Sub Site ID  Sub Param 1  \
# 3050 NaN    NaN  ClickToDownload     NaN          NaN          NaN
# 3051 NaN    NaN  ClickToDownload     NaN          NaN          NaN
# 3052 NaN    NaN  ClickToDownload     NaN          NaN          NaN
# 3053 NaN    NaN  ClickToDownload     NaN          NaN          NaN
# 3054 NaN    NaN  ClickToDownload     NaN          NaN          NaN
#
#       Sub Param 2  Sub Param 3  Sub Param 4 Sub Param 5  Cost Model  \
# 3050          NaN          NaN          NaN         NaN         NaN
# 3051          NaN          NaN          NaN         NaN         NaN
# 3052          NaN          NaN          NaN         NaN         NaN
# 3053          NaN          NaN          NaN         NaN         NaN
# 3054          NaN          NaN          NaN         NaN         NaN
#
#       Cost Value  Cost Currency  Contributor 1 Partner  \
# 3050         NaN            NaN                    NaN
# 3051         NaN            NaN                    NaN
# 3052         NaN            NaN                    NaN
# 3053         NaN            NaN                    NaN
# 3054         NaN            NaN                    NaN
#
#       Contributor 1 Media Source  Contributor 1 Campaign  \
# 3050                         NaN                     NaN
# 3051                         NaN                     NaN
# 3052                         NaN                     NaN
# 3053                         NaN                     NaN
# 3054                         NaN                     NaN
#
#       Contributor 1 Touch Type  Contributor 1 Touch Time  \
# 3050                       NaN                       NaN
# 3051                       NaN                       NaN
# 3052                       NaN                       NaN
# 3053                       NaN                       NaN
# 3054                       NaN                       NaN
#
#       Contributor 2 Partner  Contributor 2 Media Source  \
# 3050                    NaN                         NaN
# 3051                    NaN                         NaN
# 3052                    NaN                         NaN
# 3053                    NaN                         NaN
# 3054                    NaN                         NaN
#
#       Contributor 2 Campaign  Contributor 2 Touch Type  \
# 3050                     NaN                       NaN
# 3051                     NaN                       NaN
# 3052                     NaN                       NaN
# 3053                     NaN                       NaN
# 3054                     NaN                       NaN
#
#       Contributor 2 Touch Time  Contributor 3 Partner  \
# 3050                       NaN                    NaN
# 3051                       NaN                    NaN
# 3052                       NaN                    NaN
# 3053                       NaN                    NaN
# 3054                       NaN                    NaN
#
#       Contributor 3 Media Source  Contributor 3 Campaign  \
# 3050                         NaN                     NaN
# 3051                         NaN                     NaN
# 3052                         NaN                     NaN
# 3053                         NaN                     NaN
# 3054                         NaN                     NaN
#
#       Contributor 3 Touch Type  Contributor 3 Touch Time Region Country Code  \
# 3050                       NaN                       NaN     AS           KZ
# 3051                       NaN                       NaN     AS           KZ
# 3052                       NaN                       NaN     AS           KZ
# 3053                       NaN                       NaN     AS           KZ
# 3054                       NaN                       NaN     AS           KZ
#
#      State        City Postal Code   DMA            IP   WIFI    Operator  \
# 3050   SHY    Shymkent      160000  None   95.82.80.67   True  Beeline KZ
# 3051   KZY  Kyzyl-Orda        None  None  89.36.164.74  False         NaN
# 3052   KZY  Kyzyl-Orda        None  None  89.36.164.74  False         NaN
# 3053   KZY  Kyzyl-Orda        None  None  89.36.164.74  False         NaN
# 3054   KZY  Kyzyl-Orda        None  None  89.36.164.74  False         NaN
#
#       Carrier    Language                       AppsFlyer ID  \
# 3050  Beeline     русский  1670165917556-1487722928499303855
# 3051      NaN  қазақ тілі  1670204961334-8191781773462628637
# 3052      NaN          kz  1670204961334-8191781773462628637
# 3053      NaN          kz  1670204961334-8191781773462628637
# 3054      NaN  қазақ тілі  1670204961334-8191781773462628637
#
#                             Advertising ID  IDFA  Android ID  \
# 3050  302164f2-3d4c-4911-9514-0dd3e8d27f01   NaN         NaN
# 3051  9532a8cb-e5c5-49bc-97bb-61cfd9f67689   NaN         NaN
# 3052  9532a8cb-e5c5-49bc-97bb-61cfd9f67689   NaN         NaN
# 3053  9532a8cb-e5c5-49bc-97bb-61cfd9f67689   NaN         NaN
# 3054  9532a8cb-e5c5-49bc-97bb-61cfd9f67689   NaN         NaN
#
#       Customer User ID  IMEI  IDFV Platform  Device Type OS Version  \
# 3050               NaN   NaN   NaN  android          NaN         10
# 3051          111844.0   NaN   NaN  android          NaN         11
# 3052          111844.0   NaN   NaN  android          NaN         11
# 3053          111844.0   NaN   NaN  android          NaN         11
# 3054          111844.0   NaN   NaN  android          NaN         11
#
#      App Version SDK Version              App ID App Name           Bundle ID  \
# 3050      1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# 3051      1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# 3052      1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# 3053      1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# 3054      1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
#
#       Is Retargeting  Retargeting Conversion Type Attribution Lookback  \
# 3050           False                          NaN                  30d
# 3051           False                          NaN                  30d
# 3052           False                          NaN                  30d
# 3053           False                          NaN                  30d
# 3054           False                          NaN                  30d
#
#       Reengagement Window  Is Primary Attribution  \
# 3050                  NaN                    True
# 3051                  NaN                    True
# 3052                  NaN                    True
# 3053                  NaN                    True
# 3054                  NaN                    True
#
#                                              User Agent  HTTP Referrer  \
# 3050  Dalvik/2.1.0 (Linux; U; Android 10; CPH2179 Bu...            NaN
# 3051  Dalvik/2.1.0 (Linux; U; Android 11; SM-A505FN ...            NaN
# 3052  Dalvik/2.1.0 (Linux; U; Android 11; SM-A505FN ...            NaN
# 3053  Dalvik/2.1.0 (Linux; U; Android 11; SM-A505FN ...            NaN
# 3054  Dalvik/2.1.0 (Linux; U; Android 11; SM-A505FN ...            NaN
#
#       Original URL  Blocked Reason Rule  Store Reinstall  Impressions  \
# 3050           NaN                  NaN              NaN          NaN
# 3051           NaN                  NaN              NaN          NaN
# 3052           NaN                  NaN              NaN          NaN
# 3053           NaN                  NaN              NaN          NaN
# 3054           NaN                  NaN              NaN          NaN
#
#      Conversion Type  Google Play Click Time Match Type  Mediation Network  \
# 3050         install                     NaN        srn                NaN
# 3051         install                     NaN        srn                NaN
# 3052         install                     NaN        srn                NaN
# 3053         install                     NaN        srn                NaN
# 3054         install                     NaN        srn                NaN
#
#       OAID  Deeplink URL  Google Play Install Begin Time Campaign Type  \
# 3050   NaN           NaN                             NaN            ua
# 3051   NaN           NaN                             NaN            ua
# 3052   NaN           NaN                             NaN            ua
# 3053   NaN           NaN                             NaN            ua
# 3054   NaN           NaN                             NaN            ua
#
#       Custom Data     Device Download Time        Device Model  \
# 3050          NaN  2022-11-25 08:10:51.000       OPPO::CPH2179
# 3051          NaN  2022-12-03 21:56:30.000  samsung::SM-A505FN
# 3052          NaN  2022-12-03 21:56:30.000  samsung::SM-A505FN
# 3053          NaN  2022-12-03 21:56:30.000  samsung::SM-A505FN
# 3054          NaN  2022-12-03 21:56:30.000  samsung::SM-A505FN
#
#       Monetization Network  Segment  Store Product Page Device Category  \
# 3050                   NaN      NaN                 NaN           phone
# 3051                   NaN      NaN                 NaN           phone
# 3052                   NaN      NaN                 NaN           phone
# 3053                   NaN      NaN                 NaN           phone
# 3054                   NaN      NaN                 NaN           phone
#
#      ClientState loam_amount  loan_period
# 3050         New         NaN          NaN
# 3051         Old         NaN          NaN
# 3052         NaN         NaN          NaN
# 3053         NaN        6000         10.0
# 3054         Old         NaN          NaN

# %%
import ast

x = df.iloc[2,5]

key_1 = 'ClientState'
key_2 = 'loam_amount'
key_3 = 'loan_period'

def array_parsing(key):
    value_list = []
    for i in range(len(df)):
        if 'null' in df.iloc[i,5]:
            df.iloc[i,5] = df.iloc[i,5].replace('null', 'None')
        else:
            pass
        element = ast.literal_eval(str(df.iloc[i,5]))
        if key in element:
            element = element.get(key)
            value_list.append(element)
        else:
            value_list.append(np.NaN)
    return value_list
        
df[key_1] = array_parsing(key_1)
df[key_2] = array_parsing(key_2)
df[key_3] = array_parsing(key_3)

df
# Out:
#      Attributed Touch Type Attributed Touch Time         Install Time  \
# 0                    click   2022-12-04 11:12:20  2022-12-06 23:55:06
# 1                    click   2022-12-05 11:46:08  2022-12-05 11:46:46
# 2                    click   2022-12-04 14:18:40  2022-12-06 22:48:40
# 3                    click   2022-11-30 06:07:42  2022-11-30 06:11:36
# 4               impression   2022-11-30 08:52:32  2022-11-30 09:34:54
# ...                    ...                   ...                  ...
# 3050                 click   2022-12-04 14:58:27  2022-12-04 14:58:40
# 3051                 click   2022-12-03 21:55:28  2022-12-05 01:49:23
# 3052                 click   2022-12-03 21:55:28  2022-12-05 01:49:23
# 3053                 click   2022-12-03 21:55:28  2022-12-05 01:49:23
# 3054                 click   2022-12-03 21:55:28  2022-12-05 01:49:23
#
#                Event Time               Event Name  \
# 0     2022-12-06 23:55:11               first_open
# 1     2022-12-06 22:56:28                 af_login
# 2     2022-12-06 22:48:50               first_open
# 3     2022-12-06 22:29:24                 af_login
# 4     2022-12-06 21:45:23                 af_login
# ...                   ...                      ...
# 3050  2022-12-06 00:19:00       install_kreditomat
# 3051  2022-12-06 00:15:24                 af_login
# 3052  2022-12-06 00:15:17            loan_rejected
# 3053  2022-12-06 00:15:16  submit_loan_application
# 3054  2022-12-06 00:14:06                 af_login
#
#                                             Event Value  Event Revenue  \
# 0                                                    {}            NaN
# 1                                 {"ClientState":"Old"}            NaN
# 2                                                    {}            NaN
# 3                                 {"ClientState":"Old"}            NaN
# 4                                 {"ClientState":"Old"}            NaN
# ...                                                 ...            ...
# 3050                              {"ClientState":"New"}            NaN
# 3051                              {"ClientState":"Old"}            NaN
# 3052                        {"loan_client_id":"111844"}            NaN
# 3053  {"loan_client_id":"111844","loam_amount":6000,...            NaN
# 3054                              {"ClientState":"Old"}            NaN
#
#      Event Revenue Currency  Event Revenue USD Event Source  \
# 0                       USD                NaN          SDK
# 1                       USD                NaN          SDK
# 2                       USD                NaN          SDK
# 3                       USD                NaN          SDK
# 4                       USD                NaN          SDK
# ...                     ...                ...          ...
# 3050                    USD                NaN          SDK
# 3051                    USD                NaN          SDK
# 3052                    USD                NaN          SDK
# 3053                    USD                NaN          SDK
# 3054                    USD                NaN          SDK
#
#       Is Receipt Validated  Partner       Media Source      Channel  Keywords  \
# 0                      NaN      NaN  googleadwords_int  ACI_Display       NaN
# 1                      NaN      NaN  googleadwords_int  ACI_Display       NaN
# 2                      NaN      NaN  googleadwords_int  ACI_Display       NaN
# 3                      NaN      NaN  googleadwords_int  ACI_Youtube       NaN
# 4                      NaN      NaN  googleadwords_int  ACI_Display       NaN
# ...                    ...      ...                ...          ...       ...
# 3050                   NaN      NaN  googleadwords_int  ACI_Display       NaN
# 3051                   NaN      NaN  googleadwords_int  ACI_Display       NaN
# 3052                   NaN      NaN  googleadwords_int  ACI_Display       NaN
# 3053                   NaN      NaN  googleadwords_int  ACI_Display       NaN
# 3054                   NaN      NaN  googleadwords_int  ACI_Display       NaN
#
#                  Campaign   Campaign ID                Adset      Adset ID  \
# 0     Instal - first open  1.906302e+10     Получи в 3 клика  1.432319e+11
# 1     Instal - first open  1.906810e+10   Получила за минуту  1.442988e+11
# 2     Instal - first open  1.906810e+10   Получила за минуту  1.442988e+11
# 3     Instal - first open  1.907014e+10  Срочно нужны деньги  1.435773e+11
# 4     Instal - first open  1.906302e+10     Получи в 3 клика  1.432319e+11
# ...                   ...           ...                  ...           ...
# 3050  Instal - first open  1.906302e+10   Получила за минуту  1.391446e+11
# 3051  Instal - first open  1.907017e+10  Срочно нужны деньги  1.443061e+11
# 3052  Instal - first open  1.907017e+10  Срочно нужны деньги  1.443061e+11
# 3053  Instal - first open  1.907017e+10  Срочно нужны деньги  1.443061e+11
# 3054  Instal - first open  1.907017e+10  Срочно нужны деньги  1.443061e+11
#
#       Ad  Ad ID          Ad Type        Site ID  Sub Site ID  Sub Param 1  \
# 0    NaN    NaN  ClickToDownload            NaN          NaN          NaN
# 1    NaN    NaN  ClickToDownload            NaN          NaN          NaN
# 2    NaN    NaN  ClickToDownload            NaN          NaN          NaN
# 3    NaN    NaN  ClickToDownload  YouTubeVideos          NaN          NaN
# 4    NaN    NaN  ClickToDownload            NaN          NaN          NaN
# ...   ..    ...              ...            ...          ...          ...
# 3050 NaN    NaN  ClickToDownload            NaN          NaN          NaN
# 3051 NaN    NaN  ClickToDownload            NaN          NaN          NaN
# 3052 NaN    NaN  ClickToDownload            NaN          NaN          NaN
# 3053 NaN    NaN  ClickToDownload            NaN          NaN          NaN
# 3054 NaN    NaN  ClickToDownload            NaN          NaN          NaN
#
#       Sub Param 2  Sub Param 3  Sub Param 4   Sub Param 5  Cost Model  \
# 0             NaN          NaN          NaN           NaN         NaN
# 1             NaN          NaN          NaN           NaN         NaN
# 2             NaN          NaN          NaN           NaN         NaN
# 3             NaN          NaN          NaN  engaged_view         NaN
# 4             NaN          NaN          NaN           NaN         NaN
# ...           ...          ...          ...           ...         ...
# 3050          NaN          NaN          NaN           NaN         NaN
# 3051          NaN          NaN          NaN           NaN         NaN
# 3052          NaN          NaN          NaN           NaN         NaN
# 3053          NaN          NaN          NaN           NaN         NaN
# 3054          NaN          NaN          NaN           NaN         NaN
#
#       Cost Value  Cost Currency  Contributor 1 Partner  \
# 0            NaN            NaN                    NaN
# 1            NaN            NaN                    NaN
# 2            NaN            NaN                    NaN
# 3            NaN            NaN                    NaN
# 4            NaN            NaN                    NaN
# ...          ...            ...                    ...
# 3050         NaN            NaN                    NaN
# 3051         NaN            NaN                    NaN
# 3052         NaN            NaN                    NaN
# 3053         NaN            NaN                    NaN
# 3054         NaN            NaN                    NaN
#
#       Contributor 1 Media Source  Contributor 1 Campaign  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
# ...                          ...                     ...
# 3050                         NaN                     NaN
# 3051                         NaN                     NaN
# 3052                         NaN                     NaN
# 3053                         NaN                     NaN
# 3054                         NaN                     NaN
#
#       Contributor 1 Touch Type  Contributor 1 Touch Time  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 3050                       NaN                       NaN
# 3051                       NaN                       NaN
# 3052                       NaN                       NaN
# 3053                       NaN                       NaN
# 3054                       NaN                       NaN
#
#       Contributor 2 Partner  Contributor 2 Media Source  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# ...                     ...                         ...
# 3050                    NaN                         NaN
# 3051                    NaN                         NaN
# 3052                    NaN                         NaN
# 3053                    NaN                         NaN
# 3054                    NaN                         NaN
#
#       Contributor 2 Campaign  Contributor 2 Touch Type  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ...                      ...                       ...
# 3050                     NaN                       NaN
# 3051                     NaN                       NaN
# 3052                     NaN                       NaN
# 3053                     NaN                       NaN
# 3054                     NaN                       NaN
#
#       Contributor 2 Touch Time  Contributor 3 Partner  \
# 0                          NaN                    NaN
# 1                          NaN                    NaN
# 2                          NaN                    NaN
# 3                          NaN                    NaN
# 4                          NaN                    NaN
# ...                        ...                    ...
# 3050                       NaN                    NaN
# 3051                       NaN                    NaN
# 3052                       NaN                    NaN
# 3053                       NaN                    NaN
# 3054                       NaN                    NaN
#
#       Contributor 3 Media Source  Contributor 3 Campaign  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
# ...                          ...                     ...
# 3050                         NaN                     NaN
# 3051                         NaN                     NaN
# 3052                         NaN                     NaN
# 3053                         NaN                     NaN
# 3054                         NaN                     NaN
#
#       Contributor 3 Touch Type  Contributor 3 Touch Time Region Country Code  \
# 0                          NaN                       NaN     AS           KZ
# 1                          NaN                       NaN     AS           KZ
# 2                          NaN                       NaN     AS           KZ
# 3                          NaN                       NaN     AS           KZ
# 4                          NaN                       NaN     AS           KZ
# ...                        ...                       ...    ...          ...
# 3050                       NaN                       NaN     AS           KZ
# 3051                       NaN                       NaN     AS           KZ
# 3052                       NaN                       NaN     AS           KZ
# 3053                       NaN                       NaN     AS           KZ
# 3054                       NaN                       NaN     AS           KZ
#
#      State         City Postal Code   DMA              IP   WIFI    Operator  \
# 0      AKT       Aktobe         d02  None   176.122.85.91   True  Beeline KZ
# 1      YUZ      Kaitpas      160024  None   194.0.188.112  False  Beeline KZ
# 2      KZY   Kyzyl-Orda         n00  None   95.57.233.243   True  Beeline KZ
# 3      AKM  Stepnogorsk      021500  None  146.120.93.117   True  Beeline KZ
# 4      KAR     Ivanovka      100911  None    2.135.129.82   True    ALTEL 4G
# ...    ...          ...         ...   ...             ...    ...         ...
# 3050   SHY     Shymkent      160000  None     95.82.80.67   True  Beeline KZ
# 3051   KZY   Kyzyl-Orda        None  None    89.36.164.74  False         NaN
# 3052   KZY   Kyzyl-Orda        None  None    89.36.164.74  False         NaN
# 3053   KZY   Kyzyl-Orda        None  None    89.36.164.74  False         NaN
# 3054   KZY   Kyzyl-Orda        None  None    89.36.164.74  False         NaN
#
#          Carrier    Language                       AppsFlyer ID  \
# 0      BeelineKZ     русский  1670367354422-1994174133818166914
# 1     Beeline KZ  қазақ тілі  1670240804031-8902155094375818584
# 2     Beeline KZ     русский  1670366908718-5631805336075466281
# 3     Beeline KZ          kz  1669788688911-1095085695979378145
# 4       ALTEL 4G          kz  1669800891387-1915683184375153603
# ...          ...         ...                                ...
# 3050     Beeline     русский  1670165917556-1487722928499303855
# 3051         NaN  қазақ тілі  1670204961334-8191781773462628637
# 3052         NaN          kz  1670204961334-8191781773462628637
# 3053         NaN          kz  1670204961334-8191781773462628637
# 3054         NaN  қазақ тілі  1670204961334-8191781773462628637
#
#                             Advertising ID  IDFA  Android ID  \
# 0     0a658109-ccda-4b93-a163-1a930583f74a   NaN         NaN
# 1     e0b81885-21bf-45c4-b527-ca5b0a42e357   NaN         NaN
# 2     e34274b5-a02d-4877-bae9-b80047f2ad45   NaN         NaN
# 3     45595ff8-85b8-40da-9bfd-c7c41df41413   NaN         NaN
# 4     24b6c236-94cd-46fe-b253-142ca996bb29   NaN         NaN
# ...                                    ...   ...         ...
# 3050  302164f2-3d4c-4911-9514-0dd3e8d27f01   NaN         NaN
# 3051  9532a8cb-e5c5-49bc-97bb-61cfd9f67689   NaN         NaN
# 3052  9532a8cb-e5c5-49bc-97bb-61cfd9f67689   NaN         NaN
# 3053  9532a8cb-e5c5-49bc-97bb-61cfd9f67689   NaN         NaN
# 3054  9532a8cb-e5c5-49bc-97bb-61cfd9f67689   NaN         NaN
#
#       Customer User ID  IMEI  IDFV Platform  Device Type OS Version  \
# 0                  NaN   NaN   NaN  android          NaN         12
# 1             116587.0   NaN   NaN  android          NaN         11
# 2                  NaN   NaN   NaN  android          NaN         12
# 3             112604.0   NaN   NaN  android          NaN         12
# 4             112746.0   NaN   NaN  android          NaN         11
# ...                ...   ...   ...      ...          ...        ...
# 3050               NaN   NaN   NaN  android          NaN         10
# 3051          111844.0   NaN   NaN  android          NaN         11
# 3052          111844.0   NaN   NaN  android          NaN         11
# 3053          111844.0   NaN   NaN  android          NaN         11
# 3054          111844.0   NaN   NaN  android          NaN         11
#
#      App Version SDK Version              App ID App Name           Bundle ID  \
# 0         1.0.14      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# 1         1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# 2         1.0.14      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# 3         1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# 4         1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# ...          ...         ...                 ...      ...                 ...
# 3050      1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# 3051      1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# 3052      1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# 3053      1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
# 3054      1.0.13      v6.2.0  com.tezbol.android  TEZ BOL  com.tezbol.android
#
#       Is Retargeting  Retargeting Conversion Type Attribution Lookback  \
# 0              False                          NaN                  30d
# 1              False                          NaN                  30d
# 2              False                          NaN                  30d
# 3              False                          NaN                  30d
# 4              False                          NaN                   1d
# ...              ...                          ...                  ...
# 3050           False                          NaN                  30d
# 3051           False                          NaN                  30d
# 3052           False                          NaN                  30d
# 3053           False                          NaN                  30d
# 3054           False                          NaN                  30d
#
#       Reengagement Window  Is Primary Attribution  \
# 0                     NaN                    True
# 1                     NaN                    True
# 2                     NaN                    True
# 3                     NaN                    True
# 4                     NaN                    True
# ...                   ...                     ...
# 3050                  NaN                    True
# 3051                  NaN                    True
# 3052                  NaN                    True
# 3053                  NaN                    True
# 3054                  NaN                    True
#
#                                              User Agent  HTTP Referrer  \
# 0     Dalvik/2.1.0 (Linux; U; Android 12; SM-A325F B...            NaN
# 1     Dalvik/2.1.0 (Linux; U; Android 11; SM-A505FN ...            NaN
# 2     Dalvik/2.1.0 (Linux; U; Android 12; CPH2363 Bu...            NaN
# 3     Dalvik/2.1.0 (Linux; U; Android 12; V2116 Buil...            NaN
# 4     Dalvik/2.1.0 (Linux; U; Android 11; SM-A032F B...            NaN
# ...                                                 ...            ...
# 3050  Dalvik/2.1.0 (Linux; U; Android 10; CPH2179 Bu...            NaN
# 3051  Dalvik/2.1.0 (Linux; U; Android 11; SM-A505FN ...            NaN
# 3052  Dalvik/2.1.0 (Linux; U; Android 11; SM-A505FN ...            NaN
# 3053  Dalvik/2.1.0 (Linux; U; Android 11; SM-A505FN ...            NaN
# 3054  Dalvik/2.1.0 (Linux; U; Android 11; SM-A505FN ...            NaN
#
#       Original URL  Blocked Reason Rule  Store Reinstall  Impressions  \
# 0              NaN                  NaN              NaN          NaN
# 1              NaN                  NaN              NaN          NaN
# 2              NaN                  NaN              NaN          NaN
# 3              NaN                  NaN              NaN          NaN
# 4              NaN                  NaN              NaN          NaN
# ...            ...                  ...              ...          ...
# 3050           NaN                  NaN              NaN          NaN
# 3051           NaN                  NaN              NaN          NaN
# 3052           NaN                  NaN              NaN          NaN
# 3053           NaN                  NaN              NaN          NaN
# 3054           NaN                  NaN              NaN          NaN
#
#      Conversion Type  Google Play Click Time Match Type  Mediation Network  \
# 0            install                     NaN        srn                NaN
# 1            install                     NaN        srn                NaN
# 2            install                     NaN        srn                NaN
# 3            install                     NaN        srn                NaN
# 4            install                     NaN        srn                NaN
# ...              ...                     ...        ...                ...
# 3050         install                     NaN        srn                NaN
# 3051         install                     NaN        srn                NaN
# 3052         install                     NaN        srn                NaN
# 3053         install                     NaN        srn                NaN
# 3054         install                     NaN        srn                NaN
#
#       OAID  Deeplink URL  Google Play Install Begin Time Campaign Type  \
# 0      NaN           NaN                             NaN            ua
# 1      NaN           NaN                             NaN            ua
# 2      NaN           NaN                             NaN            ua
# 3      NaN           NaN                             NaN            ua
# 4      NaN           NaN                             NaN            ua
# ...    ...           ...                             ...           ...
# 3050   NaN           NaN                             NaN            ua
# 3051   NaN           NaN                             NaN            ua
# 3052   NaN           NaN                             NaN            ua
# 3053   NaN           NaN                             NaN            ua
# 3054   NaN           NaN                             NaN            ua
#
#       Custom Data     Device Download Time        Device Model  \
# 0             NaN  2022-12-06 22:54:16.000   samsung::SM-A325F
# 1             NaN  2022-12-05 11:39:19.000  samsung::SM-A505FN
# 2             NaN  2022-12-06 22:47:57.000       OPPO::CPH2363
# 3             NaN  2022-11-30 06:09:17.000         vivo::V2116
# 4             NaN  2022-11-30 09:34:40.000   samsung::SM-A032F
# ...           ...                      ...                 ...
# 3050          NaN  2022-11-25 08:10:51.000       OPPO::CPH2179
# 3051          NaN  2022-12-03 21:56:30.000  samsung::SM-A505FN
# 3052          NaN  2022-12-03 21:56:30.000  samsung::SM-A505FN
# 3053          NaN  2022-12-03 21:56:30.000  samsung::SM-A505FN
# 3054          NaN  2022-12-03 21:56:30.000  samsung::SM-A505FN
#
#       Monetization Network  Segment  Store Product Page Device Category  \
# 0                      NaN      NaN                 NaN           phone
# 1                      NaN      NaN                 NaN           phone
# 2                      NaN      NaN                 NaN           phone
# 3                      NaN      NaN                 NaN           phone
# 4                      NaN      NaN                 NaN           phone
# ...                    ...      ...                 ...             ...
# 3050                   NaN      NaN                 NaN           phone
# 3051                   NaN      NaN                 NaN           phone
# 3052                   NaN      NaN                 NaN           phone
# 3053                   NaN      NaN                 NaN           phone
# 3054                   NaN      NaN                 NaN           phone
#
#      ClientState loam_amount  loan_period
# 0            NaN         NaN          NaN
# 1            Old         NaN          NaN
# 2            NaN         NaN          NaN
# 3            Old         NaN          NaN
# 4            Old         NaN          NaN
# ...          ...         ...          ...
# 3050         New         NaN          NaN
# 3051         Old         NaN          NaN
# 3052         NaN         NaN          NaN
# 3053         NaN        6000         10.0
# 3054         Old         NaN          NaN
#
# [3050 rows x 102 columns]

# %% [markdown]
# Сохраняем в таблицы уникальные Customer_ID по loan_rejected

# %%
lr_event = df.loc[df['Event Name'] == 'loan_rejected']

sorted = lr_event.sort_values('Customer User ID', ascending = True)
lr_event = sorted.groupby('Customer User ID').first().reset_index()

lr_event['Customer User ID'].to_excel(r'C:/Users/PC/Desktop/DataAnalytics/Events/loan_rej_customerID.xlsx', index=False)

# %% [markdown]
# Сохраняем в таблицы уникальные Customer_ID по loan_accepted

# %%
# accep_event = df.loc[df['Event Name'] == 'loan_accepted']

# sorted = accep_event.sort_values('Customer User ID', ascending = True)
# accep_event = sorted.groupby('Customer User ID').first().reset_index()

# accep_event['Customer User ID'].to_excel(r'C:/Users/PC/Desktop/DataAnalytics/Events/loan_accep_customerID.xlsx', index=False)

# %% [markdown]
# Получаем табилицу с Custumer ID и таблицу с Customer ID + Media Source

# %%
# event_with_id = df.loc[df['Event Name'] == 'submit_loan_application']
#                        # & (df['Event Name'] != 'af_login')
#                        # & (df['Event Name'] != 'af_complete_registration')]

# event_with_id[['Customer User ID', 'Media Source']].to_csv(r'C:/Users/PC/Desktop/DataAnalytics/Parser/cl_id_adv.csv', index=False, compression = None)

# # event_with_id = event_with_id.drop_duplicates(subset='Customer User ID')
# # event_with_id[['Customer User ID', 'Event Time']].to_excel(r'Desktop/DataAnalytics/Parser/cl_id.xlsx', index=False)

# %%
event_with_id[['Customer User ID', 'Event Time']]

# %%
# df[['Event Name', 'Event Value']].to_excel(r'C:/Users/PC/Desktop/DataAnalytics/Parser/events_in_arrays.xlsx', index=False)

df.to_excel(r'C:/Users/PC/Desktop/DataAnalytics/Parser/events_in_arrays.xlsx', index=False)
