# %% [markdown]
# Импорты и настройки

# %%
import requests
import pandas as pd
import numpy as np
import csv
import io
import matplotlib.pyplot as plt
import time
import inspect
from kzt_exchangerates import Rates

# %matplotlib inline

# %%
pd.set_option('display.max_columns', 50)
np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %% [markdown]
# Tez bol

# %%
# Organic = [0, 0, 0] # budget, views, clicks
# googleadwords_int = [4490, 1510000, 39100]  
# Facebook_Ads = [100, 6000, 1000]


# # bvc = [Organic, googleadwords_int, Facebook_Ads]  
# # bvc = [Organic]  
# bvc = [Organic, googleadwords_int]  


# from_date = '2022-12-01'
# to_date = '2022-12-08'



# # TEZ BOL
# app_id = 'com.tezbol.android'  # Tez bol android
# token = 'Bearer eyJhbGciOiJBMjU2S1ciLCJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwidHlwIjoiSldUIiwiemlwIjoiREVGIn0.sEVLFBUJYOA0mqDnHXn26LmhHkk9brtcqEFUQ3ff28aHsMYW4IgcRQ.rHov5TPYLC05J7FU.kPdQbwAy_6DjqVQnHgOVPNh1hLwtSdKrSPIfwVBQx22brT5CfR0-QMnh_Gmz8zFvyKOYXY2JaIfKetASeZ2FM-6VxT8b7MmFESD-McDxnSa6x_HpAbAXT2D2oqK_x7uh7WWF4eVYQTgo6M5UL8qZyg_nBH1FC3BKUxo0NEnUWtdkxlk71GbcGtP7a0Ik1NNgh7f-uFfuDbh9Kx-RhV7m5Io14MuKoh9KW1SAo__N0g2yOk5_1KDgVhGSTPtyiI34FA1O-GB569ufliR4Yo2-i9mLoCWaiJHLltxE55rp39rqLgGQiSxBpAiG-c3gHB5n8cU9pqN4cvRpMMjOTxaAE6FZYM7WlTAx80Pmqy6yVXe3dBBH9UZjpFhc5aR84y-BYU0UnrODff2KT-EjTXap2nWI0ALZCC0LvX57FZk8ZQrlV1UG6tmx2_mXgQNkAuCYNzsgRajRUf3TjLNMEwVTpn-yCYbVo9YtKumwXu9bI-iHIKqPmvr8y466bA5_zYP7MQLG75jnKWbSr3VAf87VNA.VaZ4bKqcqdREmfgWC7bBDg'

# %% [markdown]
# Creditomat.MD

# %%
# # CREDITOMAT.MD 

# app_id = 'com.kreditomatmd.dozp.ref'   # MD kreditomat android

# token = 'Bearer eyJhbGciOiJBMjU2S1ciLCJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwidHlwIjoiSldUIiwiemlwIjoiREVGIn0.Hioi6Lb0C7wwtN6_9zoigB37ukPBlJdyF5R7G3DIncShFJtPNs9h9g.eqnAjdwd28XULE_-.IZsJsJuR5e-yVrcmWoDVe-DVURRjFEsQShgWwJ9unBkxAjz72n2IBrWecP7_pA9k6mV7br73JxgvWmPB6RNwTPcPOz0FbBQQIwX-xu2iD3udokHVk3XT5aP_aMHSWkADoeyJZyImnPf10-wCi8-nJ3vivzebPl6VCi5QQ-HorU5O8PLUq9LddE-0L7gfT6S0diMY7yW1HpAGHKethpI7abCwV9_yX88tptFHlaWV8zqsHysoqZmA-6tiyloCIoGOibFgk6Ix5tJYQaZkUFbvQf5IVdwoJVe-VeGEESnBedQA3UBbpAhHB1Hp1OZeZOBUpAOQHQRZkqNvy8y9QMMkr-5-_CS567ZAtUfh3ZbMcHau63e6fsQbbWQhDWeBZ6GDm5OuAIgyyJipAyEf7_6ozL0DS00wUYrhKH1vCF4kMid7VljHcVk2s_-2u79I2ttDsQtK3DGnbSYgsGkktkQDSKGCOlRLNNkpCnHp5bnhmLEbs-BpxwIlHW7PoNi3YQriaBLJrWt1Sn-T3j8N6lIwgFDG0A.sma12W1tpVnUAojhCVLMUA'

# from_date = '2022-09-22'
# to_date = '2022-11-21'

# # media_source = 'Social_instagram'
# # media_source = 'app_land'

# media_source = ['Organic', 'Social_instagram']

# %% [markdown]
# Kreditomat.KZ

# %%
# ## KREDITOMAT.KZ

# # app_id = 'id1392973739'   # kreditomat ios
# app_id = 'com.payday.dozp.ref'   # kreditomat android

# token = 'Bearer eyJhbGciOiJBMjU2S1ciLCJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwidHlwIjoiSldUIiwiemlwIjoiREVGIn0.sEVLFBUJYOA0mqDnHXn26LmhHkk9brtcqEFUQ3ff28aHsMYW4IgcRQ.rHov5TPYLC05J7FU.kPdQbwAy_6DjqVQnHgOVPNh1hLwtSdKrSPIfwVBQx22brT5CfR0-QMnh_Gmz8zFvyKOYXY2JaIfKetASeZ2FM-6VxT8b7MmFESD-McDxnSa6x_HpAbAXT2D2oqK_x7uh7WWF4eVYQTgo6M5UL8qZyg_nBH1FC3BKUxo0NEnUWtdkxlk71GbcGtP7a0Ik1NNgh7f-uFfuDbh9Kx-RhV7m5Io14MuKoh9KW1SAo__N0g2yOk5_1KDgVhGSTPtyiI34FA1O-GB569ufliR4Yo2-i9mLoCWaiJHLltxE55rp39rqLgGQiSxBpAiG-c3gHB5n8cU9pqN4cvRpMMjOTxaAE6FZYM7WlTAx80Pmqy6yVXe3dBBH9UZjpFhc5aR84y-BYU0UnrODff2KT-EjTXap2nWI0ALZCC0LvX57FZk8ZQrlV1UG6tmx2_mXgQNkAuCYNzsgRajRUf3TjLNMEwVTpn-yCYbVo9YtKumwXu9bI-iHIKqPmvr8y466bA5_zYP7MQLG75jnKWbSr3VAf87VNA.VaZ4bKqcqdREmfgWC7bBDg'   

# from_date = '2022-09-22'
# to_date = '2022-11-21'

# Organic = [0, 0, 0] # budget, views, clicks
# googleadwords_int = [1680, 646000, 14500]  

# bvc = [Organic, googleadwords_int]

# %%
from_date = '2022-12-01'
to_date = '2022-12-08'

# TEZ BOL
app_id = 'com.tezbol.android'  # Tez bol android
token = 'Bearer eyJhbGciOiJBMjU2S1ciLCJjdHkiOiJKV1QiLCJlbmMiOiJBMjU2R0NNIiwidHlwIjoiSldUIiwiemlwIjoiREVGIn0.sEVLFBUJYOA0mqDnHXn26LmhHkk9brtcqEFUQ3ff28aHsMYW4IgcRQ.rHov5TPYLC05J7FU.kPdQbwAy_6DjqVQnHgOVPNh1hLwtSdKrSPIfwVBQx22brT5CfR0-QMnh_Gmz8zFvyKOYXY2JaIfKetASeZ2FM-6VxT8b7MmFESD-McDxnSa6x_HpAbAXT2D2oqK_x7uh7WWF4eVYQTgo6M5UL8qZyg_nBH1FC3BKUxo0NEnUWtdkxlk71GbcGtP7a0Ik1NNgh7f-uFfuDbh9Kx-RhV7m5Io14MuKoh9KW1SAo__N0g2yOk5_1KDgVhGSTPtyiI34FA1O-GB569ufliR4Yo2-i9mLoCWaiJHLltxE55rp39rqLgGQiSxBpAiG-c3gHB5n8cU9pqN4cvRpMMjOTxaAE6FZYM7WlTAx80Pmqy6yVXe3dBBH9UZjpFhc5aR84y-BYU0UnrODff2KT-EjTXap2nWI0ALZCC0LvX57FZk8ZQrlV1UG6tmx2_mXgQNkAuCYNzsgRajRUf3TjLNMEwVTpn-yCYbVo9YtKumwXu9bI-iHIKqPmvr8y466bA5_zYP7MQLG75jnKWbSr3VAf87VNA.VaZ4bKqcqdREmfgWC7bBDg'

# %%
url = f"https://hq1.appsflyer.com/api/raw-data/export/app/com.tezbol.android/in_app_events_report/v5?from={from_date}&to={to_date}&event_name=&reattr=false&additional_fields=blocked_reason_rule,store_reinstall,impressions,conversion_type,gp_click_time,match_type,mediation_network,oaid,deeplink_url,gp_install_begin,campaign_type,custom_data,device_download_time,device_model,monetization_network,segment,store_product_page,device_category"

headers = {
    "accept": "text/csv",
    "authorization": token}

urlData = requests.get(url, headers=headers).content
df = pd.read_csv(io.StringIO(urlData.decode('utf-8')), low_memory=False)

sources = list(df['Media Source'].unique())
if 'restricted' in sources:
    ind = sources.index('restricted')
    sources[ind] = 'Facebook_Ads'
else:
    pass
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_268\1652859000.py:8: DtypeWarning: Columns (28,79,80) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(io.StringIO(urlData.decode('utf-8')))

# %%
''' получаем уникальные значения"
def unique(list1):
    x = np.array(list1)
    print(np.unique(x))


unique(sources)
# Out:
# ['Facebook Ads' 'Facebook_Ads' 'appsflyer_sdk_test_int'
#  'googleadwords_int']

# %% [markdown]
# Получаем имена переменных для запроса

# %%
''' получаем имена переменных '''

def retrieve_name(var):
        for fi in reversed(inspect.stack()):
            names = [var_name for var_name, var_val in fi.frame.f_locals.items() if var_val is var]
            if len(names) > 0:
                return names[0]
            
media_source = [retrieve_name(x) for x in bvc]

media_source
# Out:
# ['Organic', 'googleadwords_int']

# %% [markdown]
# Функция обращения в AppsFlyer

# %%
def pull_request(med_sour):
    
    if med_sour == 'Facebook_Ads':
        url = f"https://hq1.appsflyer.com/api/agg-data/export/app/{app_id}/partners_report/v5?from={from_date}&to={to_date}&media_source={med_sour}&category=facebook"
    else:
        url = f"https://hq1.appsflyer.com/api/agg-data/export/app/{app_id}/partners_report/v5?from={from_date}&to={to_date}&media_source={med_sour}&category=standard"

    headers = {
        "accept": "text/csv",
        "authorization": token
    }


    urlData = requests.get(url, headers=headers).content
    rawData = pd.read_csv(io.StringIO(urlData.decode('utf-8')))
    return rawData

# %% [markdown]
# Запрос в Appsflyer

# %%
df_agre = None
if type(media_source) == list:
    for i in range(len(media_source)):
        if str(type(df_agre)) == "<class 'NoneType'>":
            df_agre = pull_request(media_source[i])
        else: 
            time.sleep(60)
            df_agre = pd.concat([df_agre, pull_request(media_source[i])])     
else:
    print(15)
    
df_agre
# Out:
#   Agency/PMD (af_prt) Media Source (pid)          Campaign (c)  Impressions  \
# 0                None            Organic                  None          NaN
# 0                None  googleadwords_int  Instal  - first open          NaN
# 1                None  googleadwords_int   Instal - first open          NaN
#
#    Clicks  CTR  Installs  Conversion Rate  Sessions  Loyal Users  \
# 0     NaN  NaN      2680              NaN         0         2194
# 0     NaN  NaN         2              NaN         7            1
# 1     NaN  NaN      7159              NaN     29108         4462
#
#    Loyal Users/Installs  Total Revenue  Total Cost  ROI    ARPU  Average eCPI  \
# 0                0.8187    -12585.9980         NaN  NaN -4.6963           NaN
# 0                0.5000         0.0000         NaN  NaN  0.0000           NaN
# 1                0.6233     -2716.0891         NaN  NaN -0.3794           NaN
#
#    af_complete_registration (Unique users)  \
# 0                                      852
# 0                                        0
# 1                                     2100
#
#    af_complete_registration (Event counter)  \
# 0                                      1130
# 0                                         0
# 1                                      2180
#
#    af_complete_registration (Sales in USD)  af_login (Unique users)  \
# 0                                      0.0                     1918
# 0                                      0.0                        0
# 1                                      0.0                     3493
#
#    af_login (Event counter)  af_login (Sales in USD)  \
# 0                     18784                      0.0
# 0                         0                      0.0
# 1                     12598                      0.0
#
#    closed_overdue (Unique users)  closed_overdue (Event counter)  \
# 0                              3                               6
# 0                              0                               0
# 1                              1                               1
#
#    closed_overdue (Sales in USD)  ...  loan_accepted_new (Sales in USD)  \
# 0                     105.254260  ...                               0.0
# 0                       0.000000  ...                               NaN
# 1                      22.229818  ...                               NaN
#
#    loan_rejected (Unique users)  loan_rejected (Event counter)  \
# 0                          1008                           5273
# 0                             0                              0
# 1                          1827                           3896
#
#    loan_rejected (Sales in USD)  loan_request (Unique users)  \
# 0                           0.0                          499
# 0                           0.0                            0
# 1                           0.0                          694
#
#    loan_request (Event counter)  loan_request (Sales in USD)  \
# 0                          2946                          0.0
# 0                             0                          0.0
# 1                          1555                          0.0
#
#    loan_request_new (Unique users)  loan_request_new (Event counter)  \
# 0                              0.0                               2.0
# 0                              NaN                               NaN
# 1                              NaN                               NaN
#
#    loan_request_new (Sales in USD)  paid (Unique users)  paid (Event counter)  \
# 0                              0.0                    4                    12
# 0                              NaN                    0                     0
# 1                              NaN                    3                     3
#
#    paid (Sales in USD)  passed_verification (Unique users)  \
# 0            146.65788                                 330
# 0              0.00000                                   0
# 1             28.64318                                 713
#
#    passed_verification (Event counter)  passed_verification (Sales in USD)  \
# 0                                  516                                 0.0
# 0                                    0                                 0.0
# 1                                  767                                 0.0
#
#    payment_completed (Unique users)  payment_completed (Event counter)  \
# 0                               1.0                                1.0
# 0                               NaN                                NaN
# 1                               NaN                                NaN
#
#    payment_completed (Sales in USD)  started_overdue (Unique users)  \
# 0                               0.0                             101
# 0                               NaN                               0
# 1                               NaN                              42
#
#    started_overdue (Event counter)  started_overdue (Sales in USD)  \
# 0                              204                      -12837.910
# 0                                0                           0.000
# 1                               50                       -2766.962
#
#    submit_loan_application (Unique users)  \
# 0                                    1145
# 0                                       0
# 1                                    1924
#
#    submit_loan_application (Event counter)  \
# 0                                     6568
# 0                                        0
# 1                                     4530
#
#    submit_loan_application (Sales in USD)
# 0                                     0.0
# 0                                     0.0
# 1                                     0.0
#
# [3 rows x 70 columns]

# %% [markdown]
# Заменяем пробелы в колонках

# %%
df_agre['Media Source (pid)'] = df_agre['Media Source (pid)'].str.replace(' ','_')

# %% [markdown]
# Группируем компании в единные источники

# %%
dfx = df_agre.groupby('Media Source (pid)').sum(numeric_only=True)
dfx
# Out:
#                     Impressions  Clicks  CTR  Installs  Conversion Rate  \
# Media Source (pid)
# Organic                     0.0     0.0  0.0      2680              0.0
# googleadwords_int           0.0     0.0  0.0      7161              0.0
#
#                     Sessions  Loyal Users  Loyal Users/Installs  \
# Media Source (pid)
# Organic                    0         2194                0.8187
# googleadwords_int      29115         4463                1.1233
#
#                     Total Revenue  Total Cost  ROI    ARPU  Average eCPI  \
# Media Source (pid)
# Organic               -12585.9980         0.0  0.0 -4.6963           0.0
# googleadwords_int      -2716.0891         0.0  0.0 -0.3794           0.0
#
#                     af_complete_registration (Unique users)  \
# Media Source (pid)
# Organic                                                 852
# googleadwords_int                                      2100
#
#                     af_complete_registration (Event counter)  \
# Media Source (pid)
# Organic                                                 1130
# googleadwords_int                                       2180
#
#                     af_complete_registration (Sales in USD)  \
# Media Source (pid)
# Organic                                                 0.0
# googleadwords_int                                       0.0
#
#                     af_login (Unique users)  af_login (Event counter)  \
# Media Source (pid)
# Organic                                1918                     18784
# googleadwords_int                      3493                     12598
#
#                     af_login (Sales in USD)  closed_overdue (Unique users)  \
# Media Source (pid)
# Organic                                 0.0                              3
# googleadwords_int                       0.0                              1
#
#                     closed_overdue (Event counter)  \
# Media Source (pid)
# Organic                                          6
# googleadwords_int                                1
#
#                     closed_overdue (Sales in USD)  \
# Media Source (pid)
# Organic                                105.254260
# googleadwords_int                       22.229818
#
#                     contract_signed (Unique users)  \
# Media Source (pid)
# Organic                                         91
# googleadwords_int                               63
#
#                     contract_signed (Event counter)  \
# Media Source (pid)
# Organic                                         323
# googleadwords_int                                72
#
#                     contract_signed (Sales in USD)  ...  \
# Media Source (pid)                                  ...
# Organic                                        0.0  ...
# googleadwords_int                              0.0  ...
#
#                     loan_accepted_new (Sales in USD)  \
# Media Source (pid)
# Organic                                          0.0
# googleadwords_int                                0.0
#
#                     loan_rejected (Unique users)  \
# Media Source (pid)
# Organic                                     1008
# googleadwords_int                           1827
#
#                     loan_rejected (Event counter)  \
# Media Source (pid)
# Organic                                      5273
# googleadwords_int                            3896
#
#                     loan_rejected (Sales in USD)  loan_request (Unique users)  \
# Media Source (pid)
# Organic                                      0.0                          499
# googleadwords_int                            0.0                          694
#
#                     loan_request (Event counter)  loan_request (Sales in USD)  \
# Media Source (pid)
# Organic                                     2946                          0.0
# googleadwords_int                           1555                          0.0
#
#                     loan_request_new (Unique users)  \
# Media Source (pid)
# Organic                                         0.0
# googleadwords_int                               0.0
#
#                     loan_request_new (Event counter)  \
# Media Source (pid)
# Organic                                          2.0
# googleadwords_int                                0.0
#
#                     loan_request_new (Sales in USD)  paid (Unique users)  \
# Media Source (pid)
# Organic                                         0.0                    4
# googleadwords_int                               0.0                    3
#
#                     paid (Event counter)  paid (Sales in USD)  \
# Media Source (pid)
# Organic                               12            146.65788
# googleadwords_int                      3             28.64318
#
#                     passed_verification (Unique users)  \
# Media Source (pid)
# Organic                                            330
# googleadwords_int                                  713
#
#                     passed_verification (Event counter)  \
# Media Source (pid)
# Organic                                             516
# googleadwords_int                                   767
#
#                     passed_verification (Sales in USD)  \
# Media Source (pid)
# Organic                                            0.0
# googleadwords_int                                  0.0
#
#                     payment_completed (Unique users)  \
# Media Source (pid)
# Organic                                          1.0
# googleadwords_int                                0.0
#
#                     payment_completed (Event counter)  \
# Media Source (pid)
# Organic                                           1.0
# googleadwords_int                                 0.0
#
#                     payment_completed (Sales in USD)  \
# Media Source (pid)
# Organic                                          0.0
# googleadwords_int                                0.0
#
#                     started_overdue (Unique users)  \
# Media Source (pid)
# Organic                                        101
# googleadwords_int                               42
#
#                     started_overdue (Event counter)  \
# Media Source (pid)
# Organic                                         204
# googleadwords_int                                50
#
#                     started_overdue (Sales in USD)  \
# Media Source (pid)
# Organic                                 -12837.910
# googleadwords_int                        -2766.962
#
#                     submit_loan_application (Unique users)  \
# Media Source (pid)
# Organic                                               1145
# googleadwords_int                                     1924
#
#                     submit_loan_application (Event counter)  \
# Media Source (pid)
# Organic                                                6568
# googleadwords_int                                      4530
#
#                     submit_loan_application (Sales in USD)
# Media Source (pid)
# Organic                                                0.0
# googleadwords_int                                      0.0
#
# [2 rows x 67 columns]

# %%
dfx.columns
# Out:
# Index(['Impressions', 'Clicks', 'CTR', 'Installs', 'Conversion Rate',
#        'Sessions', 'Loyal Users', 'Loyal Users/Installs', 'Total Revenue',
#        'Total Cost', 'ROI', 'ARPU', 'Average eCPI',
#        'af_complete_registration (Unique users)',
#        'af_complete_registration (Event counter)',
#        'af_complete_registration (Sales in USD)', 'af_login (Unique users)',
#        'af_login (Event counter)', 'af_login (Sales in USD)',
#        'closed_overdue (Unique users)', 'closed_overdue (Event counter)',
#        'closed_overdue (Sales in USD)', 'contract_signed (Unique users)',
#        'contract_signed (Event counter)', 'contract_signed (Sales in USD)',
#        'contract_signed_new (Unique users)',
#        'contract_signed_new (Event counter)',
#        'contract_signed_new (Sales in USD)', 'first_open (Unique users)',
#        'first_open (Event counter)', 'first_open (Sales in USD)',
#        'first_open_new (Unique users)', 'first_open_new (Event counter)',
#        'first_open_new (Sales in USD)', 'install_kreditomat (Unique users)',
#        'install_kreditomat (Event counter)',
#        'install_kreditomat (Sales in USD)', 'loan_accepted (Unique users)',
#        'loan_accepted (Event counter)', 'loan_accepted (Sales in USD)',
#        'loan_accepted_new (Unique users)', 'loan_accepted_new (Event counter)',
#        'loan_accepted_new (Sales in USD)', 'loan_rejected (Unique users)',
#        'loan_rejected (Event counter)', 'loan_rejected (Sales in USD)',
#        'loan_request (Unique users)', 'loan_request (Event counter)',
#        'loan_request (Sales in USD)', 'loan_request_new (Unique users)',
#        'loan_request_new (Event counter)', 'loan_request_new (Sales in USD)',
#        'paid (Unique users)', 'paid (Event counter)', 'paid (Sales in USD)',
#        'passed_verification (Unique users)',
#        'passed_verification (Event counter)',
#        'passed_verification (Sales in USD)',
#        'payment_completed (Unique users)', 'payment_completed (Event counter)',
#        'payment_completed (Sales in USD)', 'started_overdue (Unique users)',
#        'started_overdue (Event counter)', 'started_overdue (Sales in USD)',
#        'submit_loan_application (Unique users)',
#        'submit_loan_application (Event counter)',
#        'submit_loan_application (Sales in USD)'],
#       dtype='object')

# %%
if 'af_login (Sales in KZT)' in dfx.columns:
    print(1)
else:
    print(2)
# Out:
# 2

# %% [markdown]
# Удаляем лишние колонки

# %%
df = dfx.copy()



''' удаляем лишние колонки '''
try: 
    df = df.drop([
                 'Impressions',
                 'CTR',
                 'Conversion Rate',
                 'Total Revenue',
                 'Total Cost',
                 'af_login (Unique users)',
                 'loan_accepted (Unique users)',
                 'install_kreditomat (Event counter)',
                 'ROI',
                 'ARPU',
                 'Loyal Users',
                 'Loyal Users/Installs',
                 'loan_rejected (Unique users)',
                 'Average eCPI',
                 'install_kreditomat (Unique users)',
                 'af_complete_registration (Unique users)',
                 'submit_loan_application (Unique users)'], axis=1)
except:
    df = df.drop([
                'Impressions',
                 'CTR',
                 'Conversion Rate',
                 'Total Revenue',
                 'Total Cost',
                 'af_login (Unique users)',
                 'loan_accepted (Unique users)',
                 'install_kreditomat (Event counter)',
                 'ROI',
                 'ARPU',
                 'Loyal Users',
                 'Loyal Users/Installs',
                 'loan_rejected (Unique users)',
                 'Average eCPI',
                 'install_kreditomat (Unique users)',
                 'submit_loan_application (Unique users)'], axis=1)

    
try:
    if 'af_login (Sales in KZT)' in df.columns:
        df = df.drop([
                 'af_complete_registration (Sales in KZT)',
                 'af_login (Sales in KZT)',
                 'install_kreditomat (Sales in KZT)',
                 'loan_accepted (Sales in KZT)',
                 'loan_rejected (Sales in KZT)',
                 'submit_loan_application (Sales in KZT)'], axis=1)
    else:    
        df = df.drop([
                 'af_complete_registration (Sales in USD)',
                 'af_login (Sales in USD)',
                 'install_kreditomat (Sales in USD)',
                 'loan_accepted (Sales in USD)',
                 'loan_rejected (Sales in USD)',
                 'submit_loan_application (Sales in USD)'], axis=1)
except:
    if 'af_login (Sales in KZT)' in df.columns:
        df = df.drop([
                 'af_login (Sales in KZT)',
                 'install_kreditomat (Sales in KZT)',
                 'loan_accepted (Sales in KZT)',
                 'loan_rejected (Sales in KZT)',
                 'submit_loan_application (Sales in KZT)'], axis=1)
    else:    
        df = df.drop([
                 'af_login (Sales in USD)',
                 'install_kreditomat (Sales in USD)',
                 'loan_accepted (Sales in USD)',
                 'loan_rejected (Sales in USD)',
                 'submit_loan_application (Sales in USD)'], axis=1)
    
# # transposition columns
# df = df[['Media Source (pid)', 'Campaign (c)', 'Budget', 'Sessions', 'install_kreditomat (Event counter)', 'af_login (Event counter)', 'submit_loan_application (Event counter)', 'loan_rejected (Event counter)', 'loan_accepted (Event counter)']]
# df

# transposition columns without BUDGET
df = df[['Sessions', 'Installs', 'af_login (Event counter)', 'submit_loan_application (Event counter)', 'loan_rejected (Event counter)', 'loan_accepted (Event counter)']]
df
# Out:
#                     Sessions  Installs  af_login (Event counter)  \
# Media Source (pid)
# Organic                    0      2680                     18784
# googleadwords_int      29115      7161                     12598
#
#                     submit_loan_application (Event counter)  \
# Media Source (pid)
# Organic                                                6568
# googleadwords_int                                      4530
#
#                     loan_rejected (Event counter)  \
# Media Source (pid)
# Organic                                      5273
# googleadwords_int                            3896
#
#                     loan_accepted (Event counter)
# Media Source (pid)
# Organic                                       864
# googleadwords_int                             242

# %% [markdown]
# Считаем конверсии

# %%
df
# Out:
#                     Sessions  Installs  af_login (Event counter)  \
# Media Source (pid)
# Organic                    0      2680                     18784
# googleadwords_int      29115      7161                     12598
#
#                     submit_loan_application (Event counter)  \
# Media Source (pid)
# Organic                                                6568
# googleadwords_int                                      4530
#
#                     loan_rejected (Event counter)  \
# Media Source (pid)
# Organic                                      5273
# googleadwords_int                            3896
#
#                     loan_accepted (Event counter)
# Media Source (pid)
# Organic                                       864
# googleadwords_int                             242

# %% [markdown]
# Добавляем данные в таблицу по бюджету, просмотрам и кликам

# %%
''' add budgets, views, clicks '''
 
df_bvc = pd.DataFrame(index=['Budget', 'Views', 'Clicks'])

for i in range(len(bvc)): 
    df_bvc.insert(0, f"{retrieve_name(bvc[i])}", bvc[i], True)


df_bvc = df_bvc.T

df_bvc
# Out:
#                    Budget    Views  Clicks
# googleadwords_int    4490  1510000   39100
# Organic                 0        0       0

# %% [markdown]
# Объединение таблиц с бюджетом и с appsflyer

# %%
''' объединяюю таблицы '''

df = pd.concat([df_bvc, df], axis=1, join="inner")

# %% [markdown]
# Сортируем по колонке 'Installs'

# %%
''' сортирую по установкам '''

df = df.sort_values(by='Installs', ascending=False)
df
# Out:
#                    Budget    Views  Clicks  Sessions  Installs  \
# googleadwords_int    4490  1510000   39100     29115      7161
# Organic                 0        0       0         0      2680
#
#                    af_login (Event counter)  \
# googleadwords_int                     12598
# Organic                               18784
#
#                    submit_loan_application (Event counter)  \
# googleadwords_int                                     4530
# Organic                                               6568
#
#                    loan_rejected (Event counter)  \
# googleadwords_int                           3896
# Organic                                     5273
#
#                    loan_accepted (Event counter)
# googleadwords_int                            242
# Organic                                      864

# %% [markdown]
# Считаем финансовые метрики

# %%
def trunc(values, decs=0):
    return np.trunc(values * 10 ** decs) / (10 ** decs)


''' AMOUNT PERCENT '''

# получаем Clicks_to_Installs
cti = df[['Installs']].to_numpy() / (df[['Clicks']].to_numpy() / 100)
cti = trunc(cti, decs=1)
df.insert(4, "Clicks_to_Installs %", cti, True)


''' FINANCIAL '''

# получаем CPAp
cpap = df[['Budget']].to_numpy() / df[['loan_accepted (Event counter)']].to_numpy()
cpap = trunc(cpap, decs=2)
df.insert(3, "CPAp", cpap, True)

# получаем CPSu
cpsu = trunc(df[['Budget']].to_numpy() / df[['submit_loan_application (Event counter)']].to_numpy(), decs=2)
df.insert(3, "CPSu", cpsu, True)

# получаем CPI
cpi = trunc(df[['Budget']].to_numpy() / df[['Installs']].to_numpy(), decs=2)
df.insert(3, "CPI", cpi, True)

# получаем CPC
cpc = trunc(df[['Budget']].to_numpy() / df[['Clicks']].to_numpy(), decs=2)
df.insert(3, "CPC", cpc, True)


# получаем Installs_to_Login
itlo = trunc(df[['af_login (Event counter)']].to_numpy() / (df[['Installs']].to_numpy() / 100), decs=1)
df.insert(2, "Installs_to_Login %", itlo, True)

# получаем Installs_to_Submit
itsu = trunc(df[['submit_loan_application (Event counter)']].to_numpy() / (df[['Installs']].to_numpy() / 100),
                 decs=1)
df.insert(4, "Installs_to_Submit %", itsu, True)

# получаем Installs_to_Accepted
itap = trunc(df[['loan_accepted (Event counter)']].to_numpy() / (df[['Installs']].to_numpy() / 100),
                 decs=1)
df.insert(4, "Installs_to_Accepted %", itap, True)

# # получаем Submit_to_Rejected
# stre = trunc(df[['loan_rejected (Event counter)']].to_numpy() / (
#             df[['submit_loan_application (Event counter)']].to_numpy() / 100), decs=1)
# df.insert(6, "Submit_to_Rejected %", stre, True)

# # получаем Submit_to_Accepted
# stap = trunc(df[['loan_accepted (Event counter)']].to_numpy() / (
#             df[['submit_loan_application (Event counter)']].to_numpy() / 100), decs=1)
# df.insert(8, "Submit_to_Accepted %", stap, True)

# # получаем Submit_to_Lost
# stl = (100 - (stre + stap))
# df.insert(10, "Submit_to_Lost %", stl, True)

# %% [markdown]
# Меняем несущствующие значения на ноль

# %%
df = df.replace([-np.inf, np.inf], [0, 0])
df.fillna(0,  inplace=True)
df
# Out:
#                    Budget    Views  Installs_to_Login %  Clicks  \
# googleadwords_int    4490  1510000                175.9   39100
# Organic                 0        0                700.8       0
#
#                    Installs_to_Accepted %  Installs_to_Submit %   CPC   CPI  \
# googleadwords_int                     3.3                  63.2  0.11  0.62
# Organic                              32.2                 245.0  0.00  0.00
#
#                    CPSu   CPAp  Sessions  Clicks_to_Installs %  Installs  \
# googleadwords_int  0.99  18.55     29115                  18.3      7161
# Organic            0.00   0.00         0                   0.0      2680
#
#                    af_login (Event counter)  \
# googleadwords_int                     12598
# Organic                               18784
#
#                    submit_loan_application (Event counter)  \
# googleadwords_int                                     4530
# Organic                                               6568
#
#                    loan_rejected (Event counter)  \
# googleadwords_int                           3896
# Organic                                     5273
#
#                    loan_accepted (Event counter)
# googleadwords_int                            242
# Organic                                      864

# %% [markdown]
# Делаем расстановку колонок в удобном порядке

# %%
df = df[['Budget',
                'Views', 
                'Clicks', 
                'CPC',
                'Clicks_to_Installs %',
                'Installs',
               'CPI',
               'Installs_to_Login %',
               'af_login (Event counter)',
               'Installs_to_Submit %',
               'submit_loan_application (Event counter)',
               'CPSu',
               # 'Submit_to_Rejected %',
               'loan_rejected (Event counter)',
               # 'Submit_to_Accepted %',
               'Installs_to_Accepted %',
               'loan_accepted (Event counter)',
               'CPAp',
               # 'Submit_to_Lost %'
                   ]]

df
# Out:
#                    Budget    Views  Clicks   CPC  Clicks_to_Installs %  \
# googleadwords_int    4490  1510000   39100  0.11                  18.3
# Organic                 0        0       0  0.00                   0.0
#
#                    Installs   CPI  Installs_to_Login %  \
# googleadwords_int      7161  0.62                175.9
# Organic                2680  0.00                700.8
#
#                    af_login (Event counter)  Installs_to_Submit %  \
# googleadwords_int                     12598                  63.2
# Organic                               18784                 245.0
#
#                    submit_loan_application (Event counter)  CPSu  \
# googleadwords_int                                     4530  0.99
# Organic                                               6568  0.00
#
#                    loan_rejected (Event counter)  Installs_to_Accepted %  \
# googleadwords_int                           3896                     3.3
# Organic                                     5273                    32.2
#
#                    loan_accepted (Event counter)   CPAp
# googleadwords_int                            242  18.55
# Organic                                      864   0.00

# %% [markdown]
# Получаем курс Тенге и копируем таблицу с финансовыми метриками

# %%
''' add USD to KZT cotverter '''

rates = Rates()

KZTUSD = rates.get_exchange_rate("USD", from_kzt=True)

# create copy of table with KZT 
df_kzt = df.copy()
financial_metrics = ['Budget', 'CPC', 'CPI', 'CPSu', 'CPAp']
df_kzt[financial_metrics] = df_kzt[financial_metrics] * KZTUSD
df_kzt
# Out:
#                       Budget    Views  Clicks      CPC  Clicks_to_Installs %  \
# googleadwords_int  2120043.3  1510000   39100  51.9387                  18.3
# Organic                  0.0        0       0   0.0000                   0.0
#
#                    Installs       CPI  Installs_to_Login %  \
# googleadwords_int      7161  292.7454                175.9
# Organic                2680    0.0000                700.8
#
#                    af_login (Event counter)  Installs_to_Submit %  \
# googleadwords_int                     12598                  63.2
# Organic                               18784                 245.0
#
#                    submit_loan_application (Event counter)      CPSu  \
# googleadwords_int                                     4530  467.4483
# Organic                                               6568    0.0000
#
#                    loan_rejected (Event counter)  Installs_to_Accepted %  \
# googleadwords_int                           3896                     3.3
# Organic                                     5273                    32.2
#
#                    loan_accepted (Event counter)       CPAp
# googleadwords_int                            242  8758.7535
# Organic                                      864     0.0000

# %% [markdown]
# Создаем визуализацию таблицы

# %%
plt.bar(df_kzt.index[[0, 1]], df_kzt.iloc[list(df_kzt['Budget'] > 0)].Budget.values)
plt.title('Budget')
# Out:
# Text(0.5, 1.0, 'Budget')

# %%
plt.subplot(2, 1, 1)
plt.bar(df_kzt.index[[0, 1]], df_kzt.iloc[list(df_kzt['CPC'] > 0)].CPC.values)
plt.title('CPC')

plt.subplot(2, 1, 2)
plt.bar(df_kzt.index[[0, 1]], df_kzt.iloc[list(df_kzt['CPI'] > 0)].CPI.values)
plt.title('CPI')
# Out:
# Text(0.5, 1.0, 'CPI')

# %%
plt.subplot(2, 1, 1)
plt.bar(df_kzt.index[[0, 1]], df_kzt.iloc[list(df_kzt['CPSu'] > 0)].CPSu.values)
plt.title('CPSu')

plt.subplot(2, 1,2)
plt.bar(df_kzt.index[[0, 1]], df_kzt.iloc[list(df_kzt['CPAp'] > 0)].CPAp.values)
plt.title('CPAp')
# Out:
# Text(0.5, 1.0, 'CPAp')

# %%
 df_kzt.iloc[list(df_kzt['CPSu'] > 0)].CPSu.values
# Out:
# array([467.4483])
